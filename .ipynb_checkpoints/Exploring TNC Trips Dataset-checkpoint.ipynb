# %%
import pandas as pd
import numpy as np
import sys 
import datetime
import os
import matplotlib as plt

# %matplotlib inline

# %%
agg = {'Fare':'mean','Trip Total':'mean','Trip Miles':'sum','Trips Pooled':'sum','PRIVATE_TRIPS':'sum','SHARED_TRIPS':'sum','TRIPS':'sum'}

# %%
def clean_float_cols(x):
    x = x.replace(',','')
    x = float(x)
    
    return x

# %%
def processRawData(infile, outfile):
        """
        Reads data, cleans it, processes it, and writes it to an HDF5 file.
        
        infile  - in raw CSV format
        outfile - output file name in h5 format
        outkey = name of table in output file
        """
        
        print(datetime.datetime.now().ctime(), 'Converting raw data in file: ', infile)
        
        # set up the reader
        reader = pd.read_csv(infile,  
                         iterator = True, 
                         sep = ',', 
        parse_dates = ['Trip Start Timestamp','Trip End Timestamp'], chunksize= 25000)

        # establish the writer and clear any table with that file name
        store = pd.HDFStore(outfile)

        # iterate through chunk by chunk so we don't run out of memory
        rowsRead    = 0
        rowsWritten_weekday = 0
        rowsWritten_weekend = 0
        
        for chunk in reader:   

            rowsRead += len(chunk)
            
            #drop TNC trips that have a missing value for dropoff or pickup census tract
            #there are roughly 40 million trips with at least one end outside of Chicago
            ## These are trips outside of chicago and will be dropped for now
            ### Need to look into including them... depends on the inclusion of external trips in the chicago ABM
            chunk = chunk.dropna(subset = ['Pickup Census Tract', 'Dropoff Census Tract'])
            
            #keep only the columns of interest
            chunk = chunk[['Trip Start Timestamp', 'Trip End Timestamp', 'Trip Seconds',
       'Trip Miles', 'Pickup Census Tract', 'Dropoff Census Tract',
       'Fare', 'Tip','Additional Charges', 'Trip Total', 'Shared Trip Authorized', 'Trips Pooled']]
            
            #convert columns from a string because it caused problems
            convert_cols = ['Trip Seconds','Trip Miles', 'Pickup Census Tract', 'Dropoff Census Tract','Fare', 
                            'Tip','Additional Charges', 'Trip Total', 'Trips Pooled']
        
            for column in convert_cols:
                chunk[column] = chunk[column].astype(str).apply(lambda x: x.replace(',',''))
                chunk[column] = chunk[column].astype(float)
           
            chunk['YEAR'], chunk['MONTH'], chunk['DOW'], chunk['HOUR'] = chunk['Trip Start Timestamp'].dt.year, chunk['Trip Start Timestamp'].dt.month, chunk['Trip Start Timestamp'].dt.weekday, chunk['Trip Start Timestamp'].dt.hour
            
            chunk_weekday = chunk[chunk['DOW'].isin([0,1,2,3,4])]
            chunk_weekend = chunk[chunk['DOW'].isin([5,6])]

            chunk_weekday_2 = chunk_weekday[chunk_weekday['HOUR'].isin([6])]
            chunk_weekday_3 = chunk_weekday[chunk_weekday['HOUR'].isin([7,8])]
            chunk_weekday_4 = chunk_weekday[chunk_weekday['HOUR'].isin([9])]
            chunk_weekday_5 = chunk_weekday[chunk_weekday['HOUR'].isin([10,11,12,13])]
            chunk_weekday_6 = chunk_weekday[chunk_weekday['HOUR'].isin([14,15])]
            chunk_weekday_7 = chunk_weekday[chunk_weekday['HOUR'].isin([16,17])]
            chunk_weekday_8 = chunk_weekday[chunk_weekday['HOUR'].isin([18,19])]
            chunk_weekday_1 = chunk_weekday[chunk_weekday['HOUR'].isin([20,21,22,23,24,1,2,3,4,5])]
            
            chunk_weekend_2 = chunk_weekend[chunk_weekend['HOUR'].isin([6])]
            chunk_weekend_3 = chunk_weekend[chunk_weekend['HOUR'].isin([7,8])]
            chunk_weekend_4 = chunk_weekend[chunk_weekend['HOUR'].isin([9])]
            chunk_weekend_5 = chunk_weekend[chunk_weekend['HOUR'].isin([10,11,12,13])]
            chunk_weekend_6 = chunk_weekend[chunk_weekend['HOUR'].isin([14,15])]
            chunk_weekend_7 = chunk_weekend[chunk_weekend['HOUR'].isin([16,17])]
            chunk_weekend_8 = chunk_weekend[chunk_weekend['HOUR'].isin([18,19])]
            chunk_weekend_1 = chunk_weekend[chunk_weekend['HOUR'].isin([20,21,22,23,24,1,2,3,4,5])]
            
            
            # write the data
            store.append('Weekday_1', chunk_weekday_1, data_columns = True)
            store.append('Weekday_2', chunk_weekday_2, data_columns = True)
            store.append('Weekday_3', chunk_weekday_3, data_columns = True)
            store.append('Weekday_4', chunk_weekday_4, data_columns = True)
            store.append('Weekday_5', chunk_weekday_5, data_columns = True)
            store.append('Weekday_6', chunk_weekday_6, data_columns = True)
            store.append('Weekday_7', chunk_weekday_7, data_columns = True)
            store.append('Weekday_8', chunk_weekday_8, data_columns = True)

            store.append('Weekend_1', chunk_weekend_1, data_columns = True)
            store.append('Weekend_2', chunk_weekend_2, data_columns = True)
            store.append('Weekend_3', chunk_weekend_3, data_columns = True)
            store.append('Weekend_4', chunk_weekend_4, data_columns = True)
            store.append('Weekend_5', chunk_weekend_5, data_columns = True)
            store.append('Weekend_6', chunk_weekend_6, data_columns = True)
            store.append('Weekend_7', chunk_weekend_7, data_columns = True)
            store.append('Weekend_8', chunk_weekend_8, data_columns = True)

            rowsWritten_weekday += len(chunk_weekday)
            rowsWritten_weekend += len(chunk_weekend)

            print ('Read %i rows and kept %i rows in weekday TNC table' % (rowsRead, rowsWritten_weekday))
            print ('kept ' + str(rowsWritten_weekend) + ' rows in weekend TNC table')

        store.close()
        print('Complete!!!')

# %%
#create the shared TNC trip h5 table
processRawData('C:/Workspace/TNC-Demand-Model/Inputs/Transportation_Network_Providers_-_Trips.csv', 'C:/Workspace/TNC-Demand-Model/Inputs/Chicago_TNC_Trips_20.H5')
# Out:
# Tue Jul 21 11:58:17 2020 Converting raw data in file:  C:/Workspace/TNC-Demand-Model/Inputs/Transportation_Network_Providers_-_Trips.csv
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Start Timestamp'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Trip End Timestamp'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Seconds'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Miles'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Pickup Census Tract'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Dropoff Census Tract'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Additional Charges'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Total'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Shared Trip Authorized'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Trips Pooled'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Start Timestamp_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Start Timestamp_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Start Timestamp_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip End Timestamp_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip End Timestamp_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip End Timestamp_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Seconds_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Seconds_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Seconds_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Miles_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Miles_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Miles_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Pickup Census Tract_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Pickup Census Tract_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Pickup Census Tract_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Dropoff Census Tract_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Dropoff Census Tract_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Dropoff Census Tract_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Additional Charges_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Additional Charges_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Additional Charges_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Total_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Total_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Total_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Shared Trip Authorized_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Shared Trip Authorized_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Shared Trip Authorized_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trips Pooled_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trips Pooled_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\ramu225\Anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trips Pooled_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# Read 25000 rows and kept 11348 rows in weekday TNC table
# kept 5717 rows in weekend TNC table
# Read 50000 rows and kept 22609 rows in weekday TNC table
# kept 11448 rows in weekend TNC table
# Read 75000 rows and kept 33831 rows in weekday TNC table
# kept 17150 rows in weekend TNC table
# Read 100000 rows and kept 44996 rows in weekday TNC table
# kept 22827 rows in weekend TNC table
# Read 125000 rows and kept 56335 rows in weekday TNC table
# kept 28426 rows in weekend TNC table
# Read 150000 rows and kept 67518 rows in weekday TNC table
# kept 34092 rows in weekend TNC table
# Read 175000 rows and kept 78749 rows in weekday TNC table
# kept 39683 rows in weekend TNC table
# Read 200000 rows and kept 90113 rows in weekday TNC table
# kept 45309 rows in weekend TNC table
# Read 225000 rows and kept 101435 rows in weekday TNC table
# kept 50923 rows in weekend TNC table
# Read 250000 rows and kept 112697 rows in weekday TNC table
# kept 56540 rows in weekend TNC table
# Read 275000 rows and kept 124013 rows in weekday TNC table
# kept 62248 rows in weekend TNC table
# Read 300000 rows and kept 135292 rows in weekday TNC table
# kept 67861 rows in weekend TNC table
# Read 325000 rows and kept 146553 rows in weekday TNC table
# kept 73603 rows in weekend TNC table
# Read 350000 rows and kept 157958 rows in weekday TNC table
# kept 79182 rows in weekend TNC table
# Read 375000 rows and kept 169237 rows in weekday TNC table
# kept 84883 rows in weekend TNC table
# Read 400000 rows and kept 180566 rows in weekday TNC table
# kept 90494 rows in weekend TNC table
# Read 425000 rows and kept 191896 rows in weekday TNC table
# kept 96066 rows in weekend TNC table
# Read 450000 rows and kept 203180 rows in weekday TNC table
# kept 101645 rows in weekend TNC table
# Read 475000 rows and kept 214494 rows in weekday TNC table
# kept 107324 rows in weekend TNC table
# Read 500000 rows and kept 225712 rows in weekday TNC table
# kept 112921 rows in weekend TNC table
# Read 525000 rows and kept 237016 rows in weekday TNC table
# kept 118530 rows in weekend TNC table
# Read 550000 rows and kept 248192 rows in weekday TNC table
# kept 124165 rows in weekend TNC table
# Read 575000 rows and kept 259532 rows in weekday TNC table
# kept 129863 rows in weekend TNC table
# Read 600000 rows and kept 270981 rows in weekday TNC table
# kept 135421 rows in weekend TNC table
# Read 625000 rows and kept 282296 rows in weekday TNC table
# kept 141021 rows in weekend TNC table
# Read 650000 rows and kept 293677 rows in weekday TNC table
# kept 146629 rows in weekend TNC table
# Read 675000 rows and kept 304826 rows in weekday TNC table
# kept 152351 rows in weekend TNC table
# Read 700000 rows and kept 316010 rows in weekday TNC table
# kept 158029 rows in weekend TNC table
# Read 725000 rows and kept 327332 rows in weekday TNC table
# kept 163760 rows in weekend TNC table
# Read 750000 rows and kept 338531 rows in weekday TNC table
# kept 169446 rows in weekend TNC table
# Read 775000 rows and kept 349763 rows in weekday TNC table
# kept 175054 rows in weekend TNC table
# Read 800000 rows and kept 360890 rows in weekday TNC table
# kept 180771 rows in weekend TNC table
# Read 825000 rows and kept 372124 rows in weekday TNC table
# kept 186407 rows in weekend TNC table
# Read 850000 rows and kept 383427 rows in weekday TNC table
# kept 191972 rows in weekend TNC table
# Read 875000 rows and kept 394710 rows in weekday TNC table
# kept 197660 rows in weekend TNC table
# Read 900000 rows and kept 405937 rows in weekday TNC table
# kept 203320 rows in weekend TNC table
# Read 925000 rows and kept 417177 rows in weekday TNC table
# kept 209129 rows in weekend TNC table
# Read 950000 rows and kept 428504 rows in weekday TNC table
# kept 214821 rows in weekend TNC table
# Read 975000 rows and kept 439706 rows in weekday TNC table
# kept 220478 rows in weekend TNC table
# Read 1000000 rows and kept 451014 rows in weekday TNC table
# kept 226102 rows in weekend TNC table
# Read 1025000 rows and kept 462267 rows in weekday TNC table
# kept 231761 rows in weekend TNC table
# Read 1050000 rows and kept 473649 rows in weekday TNC table
# kept 237374 rows in weekend TNC table
# Read 1075000 rows and kept 484696 rows in weekday TNC table
# kept 243039 rows in weekend TNC table
# Read 1100000 rows and kept 495950 rows in weekday TNC table
# kept 248766 rows in weekend TNC table
# Read 1125000 rows and kept 507314 rows in weekday TNC table
# kept 254277 rows in weekend TNC table
# Read 1150000 rows and kept 518501 rows in weekday TNC table
# kept 259963 rows in weekend TNC table
# Read 1175000 rows and kept 529870 rows in weekday TNC table
# kept 265637 rows in weekend TNC table
# Read 1200000 rows and kept 541072 rows in weekday TNC table
# kept 271284 rows in weekend TNC table
# Read 1225000 rows and kept 552236 rows in weekday TNC table
# kept 276959 rows in weekend TNC table
# Read 1250000 rows and kept 563377 rows in weekday TNC table
# kept 282625 rows in weekend TNC table
# Read 1275000 rows and kept 574642 rows in weekday TNC table
# kept 288132 rows in weekend TNC table
# Read 1300000 rows and kept 585958 rows in weekday TNC table
# kept 293641 rows in weekend TNC table
# Read 1325000 rows and kept 597111 rows in weekday TNC table
# kept 299333 rows in weekend TNC table
# Read 1350000 rows and kept 608303 rows in weekday TNC table
# kept 304993 rows in weekend TNC table
# Read 1375000 rows and kept 619482 rows in weekday TNC table
# kept 310645 rows in weekend TNC table
# Read 1400000 rows and kept 630655 rows in weekday TNC table
# kept 316365 rows in weekend TNC table
# Read 1425000 rows and kept 641858 rows in weekday TNC table
# kept 321973 rows in weekend TNC table
# Read 1450000 rows and kept 653129 rows in weekday TNC table
# kept 327610 rows in weekend TNC table
# Read 1475000 rows and kept 664326 rows in weekday TNC table
# kept 333205 rows in weekend TNC table
# Read 1500000 rows and kept 675632 rows in weekday TNC table
# kept 338910 rows in weekend TNC table
# Read 1525000 rows and kept 686990 rows in weekday TNC table
# kept 344558 rows in weekend TNC table
# Read 1550000 rows and kept 699395 rows in weekday TNC table
# kept 351032 rows in weekend TNC table
# Read 1575000 rows and kept 711780 rows in weekday TNC table
# kept 357544 rows in weekend TNC table
# Read 1600000 rows and kept 723990 rows in weekday TNC table
# kept 364067 rows in weekend TNC table
# Read 1625000 rows and kept 736336 rows in weekday TNC table
# kept 370748 rows in weekend TNC table
# Read 1650000 rows and kept 748747 rows in weekday TNC table
# kept 377277 rows in weekend TNC table
# Read 1675000 rows and kept 761045 rows in weekday TNC table
# kept 383907 rows in weekend TNC table
# Read 1700000 rows and kept 773340 rows in weekday TNC table
# kept 390502 rows in weekend TNC table
# Read 1725000 rows and kept 785583 rows in weekday TNC table
# kept 397128 rows in weekend TNC table
# Read 1750000 rows and kept 797978 rows in weekday TNC table
# kept 403608 rows in weekend TNC table
# Read 1775000 rows and kept 810365 rows in weekday TNC table
# kept 410143 rows in weekend TNC table
# Read 1800000 rows and kept 822643 rows in weekday TNC table
# kept 416852 rows in weekend TNC table
# Read 1825000 rows and kept 835083 rows in weekday TNC table
# kept 423379 rows in weekend TNC table
# Read 1850000 rows and kept 847407 rows in weekday TNC table
# kept 429954 rows in weekend TNC table
# Read 1875000 rows and kept 859807 rows in weekday TNC table
# kept 436512 rows in weekend TNC table
# Read 1900000 rows and kept 872120 rows in weekday TNC table
# kept 443088 rows in weekend TNC table
# Read 1925000 rows and kept 884666 rows in weekday TNC table
# kept 449635 rows in weekend TNC table
# Read 1950000 rows and kept 896927 rows in weekday TNC table
# kept 456162 rows in weekend TNC table
# Read 1975000 rows and kept 909382 rows in weekday TNC table
# kept 462676 rows in weekend TNC table
# Read 2000000 rows and kept 921829 rows in weekday TNC table
# kept 469084 rows in weekend TNC table
# Read 2025000 rows and kept 934093 rows in weekday TNC table
# kept 475700 rows in weekend TNC table
# Read 2050000 rows and kept 946292 rows in weekday TNC table
# kept 482173 rows in weekend TNC table
# Read 2075000 rows and kept 958554 rows in weekday TNC table
# kept 488732 rows in weekend TNC table
# Read 2100000 rows and kept 970904 rows in weekday TNC table
# kept 495181 rows in weekend TNC table
# Read 2125000 rows and kept 983263 rows in weekday TNC table
# kept 501729 rows in weekend TNC table
# Read 2150000 rows and kept 995783 rows in weekday TNC table
# kept 508160 rows in weekend TNC table
# Read 2175000 rows and kept 1008134 rows in weekday TNC table
# kept 514675 rows in weekend TNC table
# Read 2200000 rows and kept 1020448 rows in weekday TNC table
# kept 521165 rows in weekend TNC table
# Read 2225000 rows and kept 1032857 rows in weekday TNC table
# kept 527645 rows in weekend TNC table
# Read 2250000 rows and kept 1045187 rows in weekday TNC table
# kept 534241 rows in weekend TNC table
# Read 2275000 rows and kept 1057614 rows in weekday TNC table
# kept 540654 rows in weekend TNC table
# Read 2300000 rows and kept 1070002 rows in weekday TNC table
# kept 547119 rows in weekend TNC table
# Read 2325000 rows and kept 1082294 rows in weekday TNC table
# kept 553658 rows in weekend TNC table
# Read 2350000 rows and kept 1094577 rows in weekday TNC table
# kept 560177 rows in weekend TNC table
# Read 2375000 rows and kept 1106961 rows in weekday TNC table
# kept 566632 rows in weekend TNC table
# Read 2400000 rows and kept 1119311 rows in weekday TNC table
# kept 573131 rows in weekend TNC table
# Read 2425000 rows and kept 1131697 rows in weekday TNC table
# kept 579656 rows in weekend TNC table
# Read 2450000 rows and kept 1144188 rows in weekday TNC table
# kept 586180 rows in weekend TNC table
# Read 2475000 rows and kept 1156564 rows in weekday TNC table
# kept 592598 rows in weekend TNC table
# Read 2500000 rows and kept 1168965 rows in weekday TNC table
# kept 599112 rows in weekend TNC table
# Read 2525000 rows and kept 1181318 rows in weekday TNC table
# kept 605739 rows in weekend TNC table
# Read 2550000 rows and kept 1193668 rows in weekday TNC table
# kept 612340 rows in weekend TNC table
# Read 2575000 rows and kept 1206077 rows in weekday TNC table
# kept 618950 rows in weekend TNC table
# Read 2600000 rows and kept 1218461 rows in weekday TNC table
# kept 625479 rows in weekend TNC table
# Read 2625000 rows and kept 1230841 rows in weekday TNC table
# kept 631914 rows in weekend TNC table
# Read 2650000 rows and kept 1243258 rows in weekday TNC table
# kept 638364 rows in weekend TNC table
# Read 2675000 rows and kept 1255656 rows in weekday TNC table
# kept 644827 rows in weekend TNC table
# Read 2700000 rows and kept 1268000 rows in weekday TNC table
# kept 651433 rows in weekend TNC table
# Read 2725000 rows and kept 1280346 rows in weekday TNC table
# kept 657941 rows in weekend TNC table
# Read 2750000 rows and kept 1292677 rows in weekday TNC table
# kept 664390 rows in weekend TNC table
# Read 2775000 rows and kept 1305015 rows in weekday TNC table
# kept 671008 rows in weekend TNC table
# Read 2800000 rows and kept 1317281 rows in weekday TNC table
# kept 677525 rows in weekend TNC table
# Read 2825000 rows and kept 1329712 rows in weekday TNC table
# kept 683990 rows in weekend TNC table
# Read 2850000 rows and kept 1342156 rows in weekday TNC table
# kept 690402 rows in weekend TNC table
# Read 2875000 rows and kept 1354558 rows in weekday TNC table
# kept 696911 rows in weekend TNC table
# Read 2900000 rows and kept 1366983 rows in weekday TNC table
# kept 703357 rows in weekend TNC table
# Read 2925000 rows and kept 1379468 rows in weekday TNC table
# kept 709896 rows in weekend TNC table
# Read 2950000 rows and kept 1391887 rows in weekday TNC table
# kept 716415 rows in weekend TNC table
# Read 2975000 rows and kept 1404339 rows in weekday TNC table
# kept 722786 rows in weekend TNC table
# Read 3000000 rows and kept 1416701 rows in weekday TNC table
# kept 729279 rows in weekend TNC table
# Read 3025000 rows and kept 1429067 rows in weekday TNC table
# kept 735917 rows in weekend TNC table
# Read 3050000 rows and kept 1441463 rows in weekday TNC table
# kept 742442 rows in weekend TNC table
# Read 3075000 rows and kept 1453726 rows in weekday TNC table
# kept 749092 rows in weekend TNC table
# Read 3100000 rows and kept 1466107 rows in weekday TNC table
# kept 755660 rows in weekend TNC table
# Read 3125000 rows and kept 1478421 rows in weekday TNC table
# kept 762201 rows in weekend TNC table
# Read 3150000 rows and kept 1490768 rows in weekday TNC table
# kept 768757 rows in weekend TNC table
# Read 3175000 rows and kept 1502989 rows in weekday TNC table
# kept 775337 rows in weekend TNC table
# Read 3200000 rows and kept 1515357 rows in weekday TNC table
# kept 781963 rows in weekend TNC table
# Read 3225000 rows and kept 1527693 rows in weekday TNC table
# kept 788537 rows in weekend TNC table
# Read 3250000 rows and kept 1540202 rows in weekday TNC table
# kept 794929 rows in weekend TNC table
# Read 3275000 rows and kept 1552593 rows in weekday TNC table
# kept 801414 rows in weekend TNC table
# Read 3300000 rows and kept 1564862 rows in weekday TNC table
# kept 808034 rows in weekend TNC table
# Read 3325000 rows and kept 1577345 rows in weekday TNC table
# kept 814474 rows in weekend TNC table
# Read 3350000 rows and kept 1589600 rows in weekday TNC table
# kept 821093 rows in weekend TNC table
# Read 3375000 rows and kept 1602091 rows in weekday TNC table
# kept 827558 rows in weekend TNC table
# Read 3400000 rows and kept 1614508 rows in weekday TNC table
# kept 834077 rows in weekend TNC table
# Read 3425000 rows and kept 1626912 rows in weekday TNC table
# kept 840562 rows in weekend TNC table
# Read 3450000 rows and kept 1639206 rows in weekday TNC table
# kept 847162 rows in weekend TNC table
# Read 3475000 rows and kept 1651555 rows in weekday TNC table
# kept 853644 rows in weekend TNC table
# Read 3500000 rows and kept 1663832 rows in weekday TNC table
# kept 860247 rows in weekend TNC table
# Read 3525000 rows and kept 1676326 rows in weekday TNC table
# kept 866739 rows in weekend TNC table
# Read 3550000 rows and kept 1688616 rows in weekday TNC table
# kept 873231 rows in weekend TNC table
# Read 3575000 rows and kept 1700901 rows in weekday TNC table
# kept 879862 rows in weekend TNC table
# Read 3600000 rows and kept 1713182 rows in weekday TNC table
# kept 886461 rows in weekend TNC table
# Read 3625000 rows and kept 1725450 rows in weekday TNC table
# kept 892968 rows in weekend TNC table
# Read 3650000 rows and kept 1737920 rows in weekday TNC table
# kept 899391 rows in weekend TNC table
# Read 3675000 rows and kept 1750313 rows in weekday TNC table
# kept 906014 rows in weekend TNC table
# Read 3700000 rows and kept 1762746 rows in weekday TNC table
# kept 912476 rows in weekend TNC table
# Read 3725000 rows and kept 1775113 rows in weekday TNC table
# kept 919019 rows in weekend TNC table
# Read 3750000 rows and kept 1787512 rows in weekday TNC table
# kept 925557 rows in weekend TNC table
# Read 3775000 rows and kept 1799925 rows in weekday TNC table
# kept 932049 rows in weekend TNC table
# Read 3800000 rows and kept 1812401 rows in weekday TNC table
# kept 938482 rows in weekend TNC table
# Read 3825000 rows and kept 1824692 rows in weekday TNC table
# kept 945070 rows in weekend TNC table
# Read 3850000 rows and kept 1837049 rows in weekday TNC table
# kept 951575 rows in weekend TNC table
# Read 3875000 rows and kept 1849318 rows in weekday TNC table
# kept 958178 rows in weekend TNC table
# Read 3900000 rows and kept 1861504 rows in weekday TNC table
# kept 964740 rows in weekend TNC table
# Read 3925000 rows and kept 1873768 rows in weekday TNC table
# kept 971294 rows in weekend TNC table
# Read 3950000 rows and kept 1886188 rows in weekday TNC table
# kept 977720 rows in weekend TNC table
# Read 3975000 rows and kept 1898653 rows in weekday TNC table
# kept 984260 rows in weekend TNC table
# Read 4000000 rows and kept 1910938 rows in weekday TNC table
# kept 990843 rows in weekend TNC table
# Read 4025000 rows and kept 1923370 rows in weekday TNC table
# kept 997387 rows in weekend TNC table
# Read 4050000 rows and kept 1935734 rows in weekday TNC table
# kept 1003926 rows in weekend TNC table
# Read 4075000 rows and kept 1948040 rows in weekday TNC table
# kept 1010471 rows in weekend TNC table
# Read 4100000 rows and kept 1960292 rows in weekday TNC table
# kept 1017047 rows in weekend TNC table
# Read 4125000 rows and kept 1972778 rows in weekday TNC table
# kept 1023543 rows in weekend TNC table
# Read 4150000 rows and kept 1985130 rows in weekday TNC table
# kept 1030032 rows in weekend TNC table
# Read 4175000 rows and kept 1997523 rows in weekday TNC table
# kept 1036578 rows in weekend TNC table
# Read 4200000 rows and kept 2009819 rows in weekday TNC table
# kept 1043096 rows in weekend TNC table
# Read 4225000 rows and kept 2022168 rows in weekday TNC table
# kept 1049619 rows in weekend TNC table
# Read 4250000 rows and kept 2034568 rows in weekday TNC table
# kept 1056046 rows in weekend TNC table
# Read 4275000 rows and kept 2047070 rows in weekday TNC table
# kept 1062469 rows in weekend TNC table
# Read 4300000 rows and kept 2059464 rows in weekday TNC table
# kept 1069013 rows in weekend TNC table
# Read 4325000 rows and kept 2071752 rows in weekday TNC table
# kept 1075733 rows in weekend TNC table
# Read 4350000 rows and kept 2084009 rows in weekday TNC table
# kept 1082298 rows in weekend TNC table
# Read 4375000 rows and kept 2096417 rows in weekday TNC table
# kept 1088919 rows in weekend TNC table
# Read 4400000 rows and kept 2108845 rows in weekday TNC table
# kept 1095434 rows in weekend TNC table
# Read 4425000 rows and kept 2121259 rows in weekday TNC table
# kept 1101794 rows in weekend TNC table
# Read 4450000 rows and kept 2133536 rows in weekday TNC table
# kept 1108494 rows in weekend TNC table
# Read 4475000 rows and kept 2145948 rows in weekday TNC table
# kept 1115068 rows in weekend TNC table
# Read 4500000 rows and kept 2158394 rows in weekday TNC table
# kept 1121524 rows in weekend TNC table
# Read 4525000 rows and kept 2170829 rows in weekday TNC table
# kept 1128034 rows in weekend TNC table
# Read 4550000 rows and kept 2183257 rows in weekday TNC table
# kept 1134611 rows in weekend TNC table
# Read 4575000 rows and kept 2195654 rows in weekday TNC table
# kept 1141163 rows in weekend TNC table
# Read 4600000 rows and kept 2207985 rows in weekday TNC table
# kept 1147705 rows in weekend TNC table
# Read 4625000 rows and kept 2220342 rows in weekday TNC table
# kept 1154226 rows in weekend TNC table
# Read 4650000 rows and kept 2232628 rows in weekday TNC table
# kept 1160765 rows in weekend TNC table
# Read 4675000 rows and kept 2244904 rows in weekday TNC table
# kept 1167369 rows in weekend TNC table
# Read 4700000 rows and kept 2257435 rows in weekday TNC table
# kept 1173858 rows in weekend TNC table
# Read 4725000 rows and kept 2269879 rows in weekday TNC table
# kept 1180235 rows in weekend TNC table
# Read 4750000 rows and kept 2282317 rows in weekday TNC table
# kept 1186705 rows in weekend TNC table
# Read 4775000 rows and kept 2294521 rows in weekday TNC table
# kept 1193237 rows in weekend TNC table
# Read 4800000 rows and kept 2306972 rows in weekday TNC table
# kept 1199628 rows in weekend TNC table
# Read 4825000 rows and kept 2319363 rows in weekday TNC table
# kept 1206184 rows in weekend TNC table
# Read 4850000 rows and kept 2331735 rows in weekday TNC table
# kept 1212780 rows in weekend TNC table
# Read 4875000 rows and kept 2344064 rows in weekday TNC table
# kept 1219294 rows in weekend TNC table
# Read 4900000 rows and kept 2356250 rows in weekday TNC table
# kept 1225803 rows in weekend TNC table
# Read 4925000 rows and kept 2368543 rows in weekday TNC table
# kept 1232327 rows in weekend TNC table
# Read 4950000 rows and kept 2380888 rows in weekday TNC table
# kept 1238804 rows in weekend TNC table
# Read 4975000 rows and kept 2393258 rows in weekday TNC table
# kept 1245276 rows in weekend TNC table
# Read 5000000 rows and kept 2405691 rows in weekday TNC table
# kept 1251708 rows in weekend TNC table
# Read 5025000 rows and kept 2418206 rows in weekday TNC table
# kept 1258252 rows in weekend TNC table
# Read 5050000 rows and kept 2430529 rows in weekday TNC table
# kept 1264859 rows in weekend TNC table
# Read 5075000 rows and kept 2442864 rows in weekday TNC table
# kept 1271402 rows in weekend TNC table
# Read 5100000 rows and kept 2455320 rows in weekday TNC table
# kept 1277960 rows in weekend TNC table
# Read 5125000 rows and kept 2467753 rows in weekday TNC table
# kept 1284434 rows in weekend TNC table
# Read 5150000 rows and kept 2480028 rows in weekday TNC table
# kept 1290963 rows in weekend TNC table
# Read 5175000 rows and kept 2492504 rows in weekday TNC table
# kept 1297516 rows in weekend TNC table
# Read 5200000 rows and kept 2504796 rows in weekday TNC table
# kept 1304045 rows in weekend TNC table
# Read 5225000 rows and kept 2517137 rows in weekday TNC table
# kept 1310547 rows in weekend TNC table
# Read 5250000 rows and kept 2529556 rows in weekday TNC table
# kept 1316945 rows in weekend TNC table
# Read 5275000 rows and kept 2541937 rows in weekday TNC table
# kept 1323376 rows in weekend TNC table
# Read 5300000 rows and kept 2554339 rows in weekday TNC table
# kept 1329889 rows in weekend TNC table
# Read 5325000 rows and kept 2566588 rows in weekday TNC table
# kept 1336473 rows in weekend TNC table
# Read 5350000 rows and kept 2579109 rows in weekday TNC table
# kept 1342911 rows in weekend TNC table
# Read 5375000 rows and kept 2591459 rows in weekday TNC table
# kept 1349434 rows in weekend TNC table
# Read 5400000 rows and kept 2603829 rows in weekday TNC table
# kept 1355982 rows in weekend TNC table
# Read 5425000 rows and kept 2616262 rows in weekday TNC table
# kept 1362482 rows in weekend TNC table
# Read 5450000 rows and kept 2628679 rows in weekday TNC table
# kept 1368996 rows in weekend TNC table
# Read 5475000 rows and kept 2640989 rows in weekday TNC table
# kept 1375479 rows in weekend TNC table
# Read 5500000 rows and kept 2653456 rows in weekday TNC table
# kept 1381889 rows in weekend TNC table
# Read 5525000 rows and kept 2665902 rows in weekday TNC table
# kept 1388411 rows in weekend TNC table
# Read 5550000 rows and kept 2678180 rows in weekday TNC table
# kept 1394992 rows in weekend TNC table
# Read 5575000 rows and kept 2690551 rows in weekday TNC table
# kept 1401573 rows in weekend TNC table
# Read 5600000 rows and kept 2703039 rows in weekday TNC table
# kept 1408065 rows in weekend TNC table
# Read 5625000 rows and kept 2715394 rows in weekday TNC table
# kept 1414654 rows in weekend TNC table
# Read 5650000 rows and kept 2727703 rows in weekday TNC table
# kept 1421201 rows in weekend TNC table
# Read 5675000 rows and kept 2740132 rows in weekday TNC table
# kept 1427613 rows in weekend TNC table
# Read 5700000 rows and kept 2752563 rows in weekday TNC table
# kept 1433992 rows in weekend TNC table
# Read 5725000 rows and kept 2764933 rows in weekday TNC table
# kept 1440546 rows in weekend TNC table
# Read 5750000 rows and kept 2777217 rows in weekday TNC table
# kept 1447235 rows in weekend TNC table
# Read 5775000 rows and kept 2789574 rows in weekday TNC table
# kept 1453822 rows in weekend TNC table
# Read 5800000 rows and kept 2802051 rows in weekday TNC table
# kept 1460288 rows in weekend TNC table
# Read 5825000 rows and kept 2814357 rows in weekday TNC table
# kept 1466914 rows in weekend TNC table
# Read 5850000 rows and kept 2826861 rows in weekday TNC table
# kept 1473507 rows in weekend TNC table
# Read 5875000 rows and kept 2839288 rows in weekday TNC table
# kept 1480014 rows in weekend TNC table
# Read 5900000 rows and kept 2851547 rows in weekday TNC table
# kept 1486598 rows in weekend TNC table
# Read 5925000 rows and kept 2864012 rows in weekday TNC table
# kept 1493116 rows in weekend TNC table
# Read 5950000 rows and kept 2876444 rows in weekday TNC table
# kept 1499611 rows in weekend TNC table
# Read 5975000 rows and kept 2888871 rows in weekday TNC table
# kept 1506117 rows in weekend TNC table
# Read 6000000 rows and kept 2901238 rows in weekday TNC table
# kept 1512591 rows in weekend TNC table
# Read 6025000 rows and kept 2913748 rows in weekday TNC table
# kept 1519049 rows in weekend TNC table
# Read 6050000 rows and kept 2926026 rows in weekday TNC table
# kept 1525608 rows in weekend TNC table
# Read 6075000 rows and kept 2938467 rows in weekday TNC table
# kept 1532078 rows in weekend TNC table
# Read 6100000 rows and kept 2950829 rows in weekday TNC table
# kept 1538506 rows in weekend TNC table
# Read 6125000 rows and kept 2963151 rows in weekday TNC table
# kept 1545136 rows in weekend TNC table
# Read 6150000 rows and kept 2975496 rows in weekday TNC table
# kept 1551753 rows in weekend TNC table
# Read 6175000 rows and kept 2987824 rows in weekday TNC table
# kept 1558391 rows in weekend TNC table
# Read 6200000 rows and kept 3000203 rows in weekday TNC table
# kept 1564863 rows in weekend TNC table
# Read 6225000 rows and kept 3012558 rows in weekday TNC table
# kept 1571481 rows in weekend TNC table
# Read 6250000 rows and kept 3024878 rows in weekday TNC table
# kept 1578103 rows in weekend TNC table
# Read 6275000 rows and kept 3037130 rows in weekday TNC table
# kept 1584691 rows in weekend TNC table
# Read 6300000 rows and kept 3049532 rows in weekday TNC table
# kept 1591150 rows in weekend TNC table
# Read 6325000 rows and kept 3061939 rows in weekday TNC table
# kept 1597587 rows in weekend TNC table
# Read 6350000 rows and kept 3074254 rows in weekday TNC table
# kept 1604215 rows in weekend TNC table
# Read 6375000 rows and kept 3086567 rows in weekday TNC table
# kept 1610701 rows in weekend TNC table
# Read 6400000 rows and kept 3099012 rows in weekday TNC table
# kept 1617126 rows in weekend TNC table
# Read 6425000 rows and kept 3111354 rows in weekday TNC table
# kept 1623566 rows in weekend TNC table
# Read 6450000 rows and kept 3123738 rows in weekday TNC table
# kept 1630047 rows in weekend TNC table
# Read 6475000 rows and kept 3136102 rows in weekday TNC table
# kept 1636518 rows in weekend TNC table
# Read 6500000 rows and kept 3148447 rows in weekday TNC table
# kept 1643059 rows in weekend TNC table
# Read 6525000 rows and kept 3160893 rows in weekday TNC table
# kept 1649641 rows in weekend TNC table
# Read 6550000 rows and kept 3173286 rows in weekday TNC table
# kept 1656161 rows in weekend TNC table
# Read 6575000 rows and kept 3185728 rows in weekday TNC table
# kept 1662663 rows in weekend TNC table
# Read 6600000 rows and kept 3198016 rows in weekday TNC table
# kept 1669197 rows in weekend TNC table
# Read 6625000 rows and kept 3210151 rows in weekday TNC table
# kept 1675916 rows in weekend TNC table
# Read 6650000 rows and kept 3222421 rows in weekday TNC table
# kept 1682533 rows in weekend TNC table
# Read 6675000 rows and kept 3234718 rows in weekday TNC table
# kept 1689188 rows in weekend TNC table
# Read 6700000 rows and kept 3247073 rows in weekday TNC table
# kept 1695656 rows in weekend TNC table
# Read 6725000 rows and kept 3259451 rows in weekday TNC table
# kept 1702174 rows in weekend TNC table
# Read 6750000 rows and kept 3271947 rows in weekday TNC table
# kept 1708644 rows in weekend TNC table
# Read 6775000 rows and kept 3284155 rows in weekday TNC table
# kept 1715284 rows in weekend TNC table
# Read 6800000 rows and kept 3296472 rows in weekday TNC table
# kept 1721813 rows in weekend TNC table
# Read 6825000 rows and kept 3308813 rows in weekday TNC table
# kept 1728299 rows in weekend TNC table
# Read 6850000 rows and kept 3321072 rows in weekday TNC table
# kept 1734826 rows in weekend TNC table
# Read 6875000 rows and kept 3333189 rows in weekday TNC table
# kept 1741506 rows in weekend TNC table
# Read 6900000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 6925000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 6950000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 6975000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7000000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7025000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7050000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7075000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7100000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7125000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7150000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7175000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7200000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7225000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7250000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7275000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7300000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7325000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7350000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7375000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7400000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7425000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7450000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7475000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7500000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7525000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7550000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7575000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7600000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7625000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7650000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7675000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7700000 rows and kept 3339160 rows in weekday TNC table
# kept 1744692 rows in weekend TNC table
# Read 7725000 rows and kept 3340736 rows in weekday TNC table
# kept 1745591 rows in weekend TNC table
# Read 7750000 rows and kept 3351169 rows in weekday TNC table
# kept 1751640 rows in weekend TNC table
# Read 7775000 rows and kept 3361694 rows in weekday TNC table
# kept 1757684 rows in weekend TNC table
# Read 7800000 rows and kept 3372132 rows in weekday TNC table
# kept 1763774 rows in weekend TNC table
# Read 7825000 rows and kept 3382682 rows in weekday TNC table
# kept 1769671 rows in weekend TNC table
# Read 7850000 rows and kept 3393073 rows in weekday TNC table
# kept 1775692 rows in weekend TNC table
# Read 7875000 rows and kept 3403407 rows in weekday TNC table
# kept 1781827 rows in weekend TNC table
# Read 7900000 rows and kept 3413973 rows in weekday TNC table
# kept 1787874 rows in weekend TNC table
# Read 7925000 rows and kept 3424383 rows in weekday TNC table
# kept 1793854 rows in weekend TNC table
# Read 7950000 rows and kept 3434820 rows in weekday TNC table
# kept 1799814 rows in weekend TNC table
# Read 7975000 rows and kept 3445410 rows in weekday TNC table
# kept 1805855 rows in weekend TNC table
# Read 8000000 rows and kept 3456072 rows in weekday TNC table
# kept 1811877 rows in weekend TNC table
# Read 8025000 rows and kept 3466578 rows in weekday TNC table
# kept 1817904 rows in weekend TNC table
# Read 8050000 rows and kept 3477043 rows in weekday TNC table
# kept 1823936 rows in weekend TNC table
# Read 8075000 rows and kept 3487390 rows in weekday TNC table
# kept 1829916 rows in weekend TNC table
# Read 8100000 rows and kept 3497847 rows in weekday TNC table
# kept 1835941 rows in weekend TNC table
# Read 8125000 rows and kept 3508307 rows in weekday TNC table
# kept 1842000 rows in weekend TNC table
# Read 8150000 rows and kept 3518903 rows in weekday TNC table
# kept 1847957 rows in weekend TNC table
# Read 8175000 rows and kept 3529498 rows in weekday TNC table
# kept 1853953 rows in weekend TNC table
# Read 8200000 rows and kept 3540025 rows in weekday TNC table
# kept 1860021 rows in weekend TNC table
# Read 8225000 rows and kept 3550495 rows in weekday TNC table
# kept 1866015 rows in weekend TNC table
# Read 8250000 rows and kept 3561078 rows in weekday TNC table
# kept 1871932 rows in weekend TNC table
# Read 8275000 rows and kept 3571808 rows in weekday TNC table
# kept 1877912 rows in weekend TNC table
# Read 8300000 rows and kept 3582409 rows in weekday TNC table
# kept 1883840 rows in weekend TNC table
# Read 8325000 rows and kept 3592945 rows in weekday TNC table
# kept 1889785 rows in weekend TNC table
# Read 8350000 rows and kept 3603381 rows in weekday TNC table
# kept 1895855 rows in weekend TNC table
# Read 8375000 rows and kept 3613937 rows in weekday TNC table
# kept 1901933 rows in weekend TNC table
# Read 8400000 rows and kept 3624541 rows in weekday TNC table
# kept 1907903 rows in weekend TNC table
# Read 8425000 rows and kept 3635053 rows in weekday TNC table
# kept 1913930 rows in weekend TNC table
# Read 8450000 rows and kept 3645494 rows in weekday TNC table
# ...
# kept 32981710 rows in weekend TNC table
# Read 148700000 rows and kept 66484492 rows in weekday TNC table
# kept 32987480 rows in weekend TNC table
# Read 148725000 rows and kept 66495808 rows in weekday TNC table
# kept 32993118 rows in weekend TNC table
# Read 148750000 rows and kept 66507014 rows in weekday TNC table
# kept 32998721 rows in weekend TNC table
# Read 148775000 rows and kept 66518283 rows in weekday TNC table
# kept 33004328 rows in weekend TNC table
# Read 148800000 rows and kept 66529625 rows in weekday TNC table
# kept 33009880 rows in weekend TNC table
# Read 148825000 rows and kept 66540997 rows in weekday TNC table
# kept 33015554 rows in weekend TNC table
# Read 148850000 rows and kept 66552207 rows in weekday TNC table
# kept 33021223 rows in weekend TNC table
# Read 148875000 rows and kept 66563699 rows in weekday TNC table
# kept 33026775 rows in weekend TNC table
# Read 148900000 rows and kept 66574928 rows in weekday TNC table
# kept 33032455 rows in weekend TNC table
# Read 148925000 rows and kept 66586169 rows in weekday TNC table
# kept 33038123 rows in weekend TNC table
# Read 148950000 rows and kept 66597448 rows in weekday TNC table
# kept 33043792 rows in weekend TNC table
# Read 148975000 rows and kept 66608733 rows in weekday TNC table
# kept 33049361 rows in weekend TNC table
# Read 149000000 rows and kept 66620014 rows in weekday TNC table
# kept 33054959 rows in weekend TNC table
# Read 149025000 rows and kept 66631297 rows in weekday TNC table
# kept 33060642 rows in weekend TNC table
# Read 149050000 rows and kept 66642519 rows in weekday TNC table
# kept 33066340 rows in weekend TNC table
# Read 149075000 rows and kept 66653763 rows in weekday TNC table
# kept 33072115 rows in weekend TNC table
# Read 149100000 rows and kept 66664982 rows in weekday TNC table
# kept 33077807 rows in weekend TNC table
# Read 149125000 rows and kept 66676177 rows in weekday TNC table
# kept 33083501 rows in weekend TNC table
# Read 149150000 rows and kept 66687384 rows in weekday TNC table
# kept 33089045 rows in weekend TNC table
# Read 149175000 rows and kept 66698753 rows in weekday TNC table
# kept 33094674 rows in weekend TNC table
# Read 149200000 rows and kept 66709987 rows in weekday TNC table
# kept 33100335 rows in weekend TNC table
# Read 149225000 rows and kept 66721341 rows in weekday TNC table
# kept 33105932 rows in weekend TNC table
# Read 149250000 rows and kept 66732494 rows in weekday TNC table
# kept 33111620 rows in weekend TNC table
# Read 149275000 rows and kept 66743666 rows in weekday TNC table
# kept 33117256 rows in weekend TNC table
# Read 149300000 rows and kept 66754857 rows in weekday TNC table
# kept 33122869 rows in weekend TNC table
# Read 149325000 rows and kept 66766092 rows in weekday TNC table
# kept 33128612 rows in weekend TNC table
# Read 149350000 rows and kept 66777376 rows in weekday TNC table
# kept 33134343 rows in weekend TNC table
# Read 149375000 rows and kept 66788667 rows in weekday TNC table
# kept 33139980 rows in weekend TNC table
# Read 149400000 rows and kept 66799889 rows in weekday TNC table
# kept 33145656 rows in weekend TNC table
# Read 149425000 rows and kept 66811191 rows in weekday TNC table
# kept 33151214 rows in weekend TNC table
# Read 149450000 rows and kept 66822305 rows in weekday TNC table
# kept 33156775 rows in weekend TNC table
# Read 149475000 rows and kept 66833739 rows in weekday TNC table
# kept 33162305 rows in weekend TNC table
# Read 149500000 rows and kept 66844851 rows in weekday TNC table
# kept 33167958 rows in weekend TNC table
# Read 149525000 rows and kept 66856072 rows in weekday TNC table
# kept 33173697 rows in weekend TNC table
# Read 149550000 rows and kept 66867277 rows in weekday TNC table
# kept 33179340 rows in weekend TNC table
# Read 149575000 rows and kept 66878592 rows in weekday TNC table
# kept 33184950 rows in weekend TNC table
# Read 149600000 rows and kept 66889905 rows in weekday TNC table
# kept 33190504 rows in weekend TNC table
# Read 149625000 rows and kept 66901168 rows in weekday TNC table
# kept 33196277 rows in weekend TNC table
# Read 149650000 rows and kept 66912387 rows in weekday TNC table
# kept 33201930 rows in weekend TNC table
# Read 149675000 rows and kept 66923583 rows in weekday TNC table
# kept 33207620 rows in weekend TNC table
# Read 149700000 rows and kept 66934850 rows in weekday TNC table
# kept 33213198 rows in weekend TNC table
# Read 149725000 rows and kept 66946068 rows in weekday TNC table
# kept 33218863 rows in weekend TNC table
# Read 149750000 rows and kept 66957215 rows in weekday TNC table
# kept 33224568 rows in weekend TNC table
# Read 149775000 rows and kept 66968379 rows in weekday TNC table
# kept 33230231 rows in weekend TNC table
# Read 149800000 rows and kept 66979693 rows in weekday TNC table
# kept 33235757 rows in weekend TNC table
# Read 149825000 rows and kept 66990819 rows in weekday TNC table
# kept 33241392 rows in weekend TNC table
# Read 149850000 rows and kept 67002052 rows in weekday TNC table
# kept 33246957 rows in weekend TNC table
# Read 149875000 rows and kept 67013373 rows in weekday TNC table
# kept 33252581 rows in weekend TNC table
# Read 149900000 rows and kept 67024597 rows in weekday TNC table
# kept 33258203 rows in weekend TNC table
# Read 149925000 rows and kept 67035894 rows in weekday TNC table
# kept 33263876 rows in weekend TNC table
# Read 149950000 rows and kept 67047159 rows in weekday TNC table
# kept 33269541 rows in weekend TNC table
# Read 149975000 rows and kept 67058294 rows in weekday TNC table
# kept 33275167 rows in weekend TNC table
# Read 150000000 rows and kept 67069529 rows in weekday TNC table
# kept 33280836 rows in weekend TNC table
# Read 150025000 rows and kept 67080919 rows in weekday TNC table
# kept 33286408 rows in weekend TNC table
# Read 150050000 rows and kept 67092127 rows in weekday TNC table
# kept 33292063 rows in weekend TNC table
# Read 150075000 rows and kept 67103244 rows in weekday TNC table
# kept 33297723 rows in weekend TNC table
# Read 150100000 rows and kept 67114507 rows in weekday TNC table
# kept 33303410 rows in weekend TNC table
# Read 150125000 rows and kept 67125765 rows in weekday TNC table
# kept 33309081 rows in weekend TNC table
# Read 150150000 rows and kept 67136888 rows in weekday TNC table
# kept 33314760 rows in weekend TNC table
# Read 150175000 rows and kept 67148163 rows in weekday TNC table
# kept 33320491 rows in weekend TNC table
# Read 150200000 rows and kept 67159266 rows in weekday TNC table
# kept 33326201 rows in weekend TNC table
# Read 150225000 rows and kept 67170463 rows in weekday TNC table
# kept 33331882 rows in weekend TNC table
# Read 150250000 rows and kept 67181710 rows in weekday TNC table
# kept 33337529 rows in weekend TNC table
# Read 150275000 rows and kept 67192944 rows in weekday TNC table
# kept 33343106 rows in weekend TNC table
# Read 150300000 rows and kept 67204221 rows in weekday TNC table
# kept 33348707 rows in weekend TNC table
# Read 150325000 rows and kept 67215458 rows in weekday TNC table
# kept 33354431 rows in weekend TNC table
# Read 150350000 rows and kept 67226782 rows in weekday TNC table
# kept 33360053 rows in weekend TNC table
# Read 150375000 rows and kept 67237893 rows in weekday TNC table
# kept 33365719 rows in weekend TNC table
# Read 150400000 rows and kept 67249141 rows in weekday TNC table
# kept 33371381 rows in weekend TNC table
# Read 150425000 rows and kept 67260478 rows in weekday TNC table
# kept 33376976 rows in weekend TNC table
# Read 150450000 rows and kept 67271772 rows in weekday TNC table
# kept 33382539 rows in weekend TNC table
# Read 150475000 rows and kept 67283081 rows in weekday TNC table
# kept 33388135 rows in weekend TNC table
# Read 150500000 rows and kept 67294377 rows in weekday TNC table
# kept 33393735 rows in weekend TNC table
# Read 150525000 rows and kept 67305621 rows in weekday TNC table
# kept 33399329 rows in weekend TNC table
# Read 150550000 rows and kept 67316811 rows in weekday TNC table
# kept 33405000 rows in weekend TNC table
# Read 150575000 rows and kept 67327970 rows in weekday TNC table
# kept 33410699 rows in weekend TNC table
# Read 150600000 rows and kept 67339161 rows in weekday TNC table
# kept 33416391 rows in weekend TNC table
# Read 150625000 rows and kept 67350470 rows in weekday TNC table
# kept 33421987 rows in weekend TNC table
# Read 150650000 rows and kept 67361689 rows in weekday TNC table
# kept 33427669 rows in weekend TNC table
# Read 150675000 rows and kept 67372890 rows in weekday TNC table
# kept 33433407 rows in weekend TNC table
# Read 150700000 rows and kept 67384214 rows in weekday TNC table
# kept 33439058 rows in weekend TNC table
# Read 150725000 rows and kept 67395492 rows in weekday TNC table
# kept 33444606 rows in weekend TNC table
# Read 150750000 rows and kept 67406792 rows in weekday TNC table
# kept 33450207 rows in weekend TNC table
# Read 150775000 rows and kept 67417852 rows in weekday TNC table
# kept 33456026 rows in weekend TNC table
# Read 150800000 rows and kept 67428962 rows in weekday TNC table
# kept 33461731 rows in weekend TNC table
# Read 150825000 rows and kept 67440289 rows in weekday TNC table
# kept 33467391 rows in weekend TNC table
# Read 150850000 rows and kept 67451574 rows in weekday TNC table
# kept 33473052 rows in weekend TNC table
# Read 150875000 rows and kept 67462717 rows in weekday TNC table
# kept 33478741 rows in weekend TNC table
# Read 150900000 rows and kept 67474102 rows in weekday TNC table
# kept 33484298 rows in weekend TNC table
# Read 150925000 rows and kept 67485424 rows in weekday TNC table
# kept 33489840 rows in weekend TNC table
# Read 150950000 rows and kept 67496727 rows in weekday TNC table
# kept 33495512 rows in weekend TNC table
# Read 150975000 rows and kept 67507941 rows in weekday TNC table
# kept 33501183 rows in weekend TNC table
# Read 151000000 rows and kept 67519121 rows in weekday TNC table
# kept 33506874 rows in weekend TNC table
# Read 151025000 rows and kept 67530436 rows in weekday TNC table
# kept 33512446 rows in weekend TNC table
# Read 151050000 rows and kept 67541673 rows in weekday TNC table
# kept 33518136 rows in weekend TNC table
# Read 151075000 rows and kept 67552866 rows in weekday TNC table
# kept 33523870 rows in weekend TNC table
# Read 151100000 rows and kept 67564118 rows in weekday TNC table
# kept 33529404 rows in weekend TNC table
# Read 151125000 rows and kept 67575380 rows in weekday TNC table
# kept 33535058 rows in weekend TNC table
# Read 151150000 rows and kept 67586624 rows in weekday TNC table
# kept 33540689 rows in weekend TNC table
# Read 151175000 rows and kept 67598081 rows in weekday TNC table
# kept 33546241 rows in weekend TNC table
# Read 151200000 rows and kept 67609316 rows in weekday TNC table
# kept 33551983 rows in weekend TNC table
# Read 151225000 rows and kept 67620575 rows in weekday TNC table
# kept 33557547 rows in weekend TNC table
# Read 151250000 rows and kept 67631777 rows in weekday TNC table
# kept 33563229 rows in weekend TNC table
# Read 151275000 rows and kept 67642854 rows in weekday TNC table
# kept 33568954 rows in weekend TNC table
# Read 151300000 rows and kept 67654222 rows in weekday TNC table
# kept 33574564 rows in weekend TNC table
# Read 151325000 rows and kept 67665559 rows in weekday TNC table
# kept 33580297 rows in weekend TNC table
# Read 151350000 rows and kept 67676784 rows in weekday TNC table
# kept 33585943 rows in weekend TNC table
# Read 151375000 rows and kept 67688120 rows in weekday TNC table
# kept 33591553 rows in weekend TNC table
# Read 151400000 rows and kept 67699554 rows in weekday TNC table
# kept 33597176 rows in weekend TNC table
# Read 151425000 rows and kept 67710650 rows in weekday TNC table
# kept 33602959 rows in weekend TNC table
# Read 151450000 rows and kept 67721885 rows in weekday TNC table
# kept 33608602 rows in weekend TNC table
# Read 151475000 rows and kept 67733179 rows in weekday TNC table
# kept 33614221 rows in weekend TNC table
# Read 151500000 rows and kept 67744482 rows in weekday TNC table
# kept 33619831 rows in weekend TNC table
# Read 151525000 rows and kept 67755611 rows in weekday TNC table
# kept 33625528 rows in weekend TNC table
# Read 151550000 rows and kept 67766976 rows in weekday TNC table
# kept 33631200 rows in weekend TNC table
# Read 151575000 rows and kept 67778150 rows in weekday TNC table
# kept 33636922 rows in weekend TNC table
# Read 151600000 rows and kept 67789459 rows in weekday TNC table
# kept 33642606 rows in weekend TNC table
# Read 151625000 rows and kept 67800772 rows in weekday TNC table
# kept 33648296 rows in weekend TNC table
# Read 151650000 rows and kept 67812117 rows in weekday TNC table
# kept 33653971 rows in weekend TNC table
# Read 151675000 rows and kept 67823308 rows in weekday TNC table
# kept 33659671 rows in weekend TNC table
# Read 151700000 rows and kept 67834623 rows in weekday TNC table
# kept 33665341 rows in weekend TNC table
# Read 151725000 rows and kept 67845908 rows in weekday TNC table
# kept 33670966 rows in weekend TNC table
# Read 151750000 rows and kept 67857275 rows in weekday TNC table
# kept 33676604 rows in weekend TNC table
# Read 151775000 rows and kept 67868567 rows in weekday TNC table
# kept 33682266 rows in weekend TNC table
# Read 151800000 rows and kept 67879796 rows in weekday TNC table
# kept 33687948 rows in weekend TNC table
# Read 151825000 rows and kept 67891062 rows in weekday TNC table
# kept 33693591 rows in weekend TNC table
# Read 151850000 rows and kept 67902518 rows in weekday TNC table
# kept 33699084 rows in weekend TNC table
# Read 151875000 rows and kept 67913816 rows in weekday TNC table
# kept 33704781 rows in weekend TNC table
# Read 151900000 rows and kept 67925073 rows in weekday TNC table
# kept 33710483 rows in weekend TNC table
# Read 151925000 rows and kept 67936268 rows in weekday TNC table
# kept 33716121 rows in weekend TNC table
# Read 151950000 rows and kept 67947479 rows in weekday TNC table
# kept 33721782 rows in weekend TNC table
# Read 151975000 rows and kept 67958704 rows in weekday TNC table
# kept 33727357 rows in weekend TNC table
# Read 152000000 rows and kept 67969963 rows in weekday TNC table
# kept 33732905 rows in weekend TNC table
# Read 152025000 rows and kept 67981198 rows in weekday TNC table
# kept 33738398 rows in weekend TNC table
# Read 152050000 rows and kept 67992360 rows in weekday TNC table
# kept 33744159 rows in weekend TNC table
# Read 152075000 rows and kept 68003603 rows in weekday TNC table
# kept 33749788 rows in weekend TNC table
# Read 152100000 rows and kept 68014956 rows in weekday TNC table
# kept 33755440 rows in weekend TNC table
# Read 152125000 rows and kept 68026081 rows in weekday TNC table
# kept 33761224 rows in weekend TNC table
# Read 152150000 rows and kept 68037465 rows in weekday TNC table
# kept 33766893 rows in weekend TNC table
# Read 152175000 rows and kept 68048748 rows in weekday TNC table
# kept 33772644 rows in weekend TNC table
# Read 152200000 rows and kept 68059934 rows in weekday TNC table
# kept 33778302 rows in weekend TNC table
# Read 152225000 rows and kept 68071196 rows in weekday TNC table
# kept 33783992 rows in weekend TNC table
# Read 152250000 rows and kept 68082268 rows in weekday TNC table
# kept 33789697 rows in weekend TNC table
# Read 152275000 rows and kept 68093457 rows in weekday TNC table
# kept 33795450 rows in weekend TNC table
# Read 152300000 rows and kept 68104867 rows in weekday TNC table
# kept 33801092 rows in weekend TNC table
# Read 152325000 rows and kept 68116233 rows in weekday TNC table
# kept 33806690 rows in weekend TNC table
# Read 152350000 rows and kept 68127552 rows in weekday TNC table
# kept 33812223 rows in weekend TNC table
# Read 152375000 rows and kept 68138886 rows in weekday TNC table
# kept 33817866 rows in weekend TNC table
# Read 152400000 rows and kept 68150064 rows in weekday TNC table
# kept 33823561 rows in weekend TNC table
# Read 152425000 rows and kept 68161311 rows in weekday TNC table
# kept 33829222 rows in weekend TNC table
# Read 152450000 rows and kept 68172637 rows in weekday TNC table
# kept 33834834 rows in weekend TNC table
# Read 152475000 rows and kept 68183829 rows in weekday TNC table
# kept 33840445 rows in weekend TNC table
# Read 152496604 rows and kept 68193559 rows in weekday TNC table
# kept 33845358 rows in weekend TNC table
# Complete!!!

# %%
store.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7d09d9e55ce9> in <module>
# ----> 1 store.close()
#
# NameError: name 'store' is not defined

# %% [markdown]
# # Iterate through the tod tables to create plots of trips

# %%
tods = [1,2,3,4,5,6,7,8]

# %%
agg = {'Fare':'mean','PRIVATE_FARE':'mean','SHARED_FARE':'mean','Trip Total':'mean','Trip Miles':'sum','Trips Pooled':'sum','PRIVATE_TRIPS':'sum','SHARED_TRIPS':'sum','TRIPS':'sum'}

# %%
dows = ['Weekday', 'Weekend']

# %%
df_all = pd.DataFrame()

# %%
#df = pd.read_hdf('C:/Workspace/TNC-Demand-Model/Inputs/Chicago_TNC_Trips_20.H5', 'Weekday_1')
#df.head()
#len(df)
# Out:
# 16975608

# %%
#df = pd.read_hdf('C:/Workspace/TNC-Demand-Model/Inputs/Chicago_TNC_Trips_20.H5', 'Weekend_1')
#df.head()
#len(df)
# Out:
# 11155816

# %%
for dow in dows:
    print('Working on dow ' + dow)
    df_all = pd.DataFrame()
    
    for tod in tods:
        print("Working on tod " + str(tod))

        print('Reading in the data!')
        df = pd.read_hdf('C:/Workspace/TNC-Demand-Model/Inputs/Chicago_TNC_Trips_20.H5', key = dow + '_' + str(tod))

        print('Processing the data!')
        df['TRIPS'] = 1
        df['SHARED_TRIPS'] = np.where(df['Shared Trip Authorized'] == True, 1, 0)
        df['PRIVATE_TRIPS'] = np.where(df['Shared Trip Authorized'] == False, 1, 0)
        df['SHARED_FARE'] = np.where(df['Shared Trip Authorized'] == True, df['Fare'], np.nan)
        df['PRIVATE_FARE'] = np.where(df['Shared Trip Authorized'] == False, df['Fare'], np.nan)

        df.index = df['Trip Start Timestamp']
        df = df.groupby(by = [df.index.year,df.index.month ,df.index.day],as_index = False).agg(agg)
        print (df.index)
        df = df.groupby(by = [df.index.year,df.index.month]).mean()
        df_all = df.append(df)


        print('Making plots of the data!')
        
        plot = df['TRIPS'].plot()
        fig = plot.get_figure()
        fig.autofmt_xdate()
        fig.savefig('Data Exploration/' + dow + '/Trip Total Plots/TRIPS_20_' + str(tod) + '.pdf')
        fig.clear()

        plot = df['SHARED_TRIPS'].plot()
        fig = plot.get_figure()
        fig.autofmt_xdate()
        fig.savefig('Data Exploration/' + dow + '/Trip Total Plots/SHARED_TRIPS_20_' + str(tod) + '.pdf')
        fig.clear()

        plot = df['PRIVATE_TRIPS'].plot()
        fig = plot.get_figure()
        fig.autofmt_xdate()
        fig.savefig('Data Exploration/' + dow + '/Trip Total Plots/PRIVATE_TRIPS_20_' + str(tod) + '.pdf')
        fig.clear()

        plot = df['Fare'].plot()
        fig = plot.get_figure()
        fig.autofmt_xdate()
        fig.savefig('Data Exploration/' + dow + '/Fare Plots/Fare_20_' + str(tod) + '.pdf')
        fig.clear()

        plot = df['SHARED_FARE'].plot()
        fig = plot.get_figure()
        fig.autofmt_xdate()
        fig.savefig('Data Exploration/' + dow + '/Fare Plots/SHARED_FARE_20_' + str(tod) + '.pdf')
        fig.clear()

        plot = df['PRIVATE_FARE'].plot()
        fig = plot.get_figure()
        fig.autofmt_xdate()
        fig.savefig('Data Exploration/' + dow + '/Fare Plots/PRIVATE_FARE_20_' + str(tod) + '.pdf')
        fig.clear()

        
    df_all = df_all.groupby(by = df_all.index).agg(agg)
        
    print('Making plots of aggregated data')

    plot = df_all['TRIPS'].plot()
    fig = plot.get_figure()
    fig.autofmt_xdate()
    fig.savefig('Data Exploration/' + dow + '/Trip Total Plots/TRIPS_ALL_DAY_20.pdf')
    fig.clear()

    plot = df_all['SHARED_TRIPS'].plot()
    fig = plot.get_figure()
    fig.autofmt_xdate()
    fig.savefig('Data Exploration/' + dow + '/Trip Total Plots/SHARED_TRIPS_ALL_DAY_20.pdf')
    fig.clear()

    plot = df_all['PRIVATE_TRIPS'].plot()
    fig = plot.get_figure()
    fig.autofmt_xdate()
    fig.savefig('Data Exploration/' + dow + '/Trip Total Plots/PRIVATE_TRIPS_ALL_DAY_20.pdf')
    fig.clear()

    plot = df_all['Fare'].plot()
    fig = plot.get_figure()
    fig.autofmt_xdate()
    fig.savefig('Data Exploration/' + dow + '/Fare Plots/Fare_ALL_DAY_20.pdf')
    fig.clear()

    plot = df_all['SHARED_FARE'].plot()
    fig = plot.get_figure()
    fig.autofmt_xdate()
    fig.savefig('Data Exploration/' + dow + '/Fare Plots/SHARED_FARE_ALL_DAY_20.pdf')
    fig.clear()

    plot = df_all['PRIVATE_FARE'].plot()
    fig = plot.get_figure()
    fig.autofmt_xdate()
    fig.savefig('Data Exploration/' + dow + '/Fare Plots/PRIVATE_FARE_ALL_DAY_20.pdf')
    fig.clear()

print('Complete')
# Out:
# Working on dow Weekday
# Working on tod 1
# Reading in the data!
# Processing the data!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-c06a4852aa32> in <module>
#      18         df.index = df['Trip Start Timestamp']
#      19         df = df.groupby(by = [df.index.year,df.index.month ,df.index.day],as_index = False).agg(agg)
# ---> 20         df = df.groupby(by = [df.index.year,df.index.month]).mean()
#      21         df_all = df.append(df)
#      22
#
# AttributeError: 'Int64Index' object has no attribute 'year'
