# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Empty_Chicago_Matrix_2018_11_1')

# %%
for i in range(1,802):
    print('Working on ALT ' + str(i))
    i = "{:03d}".format(i)
    
    df['UTILITY_' + str(i)] = np.where(df['RH_' + str(i)] == 0, np.log(df['RH_'+str(i)] + 1) + 2.34*df['AIR_F_'+str(i)] + -0.66*df['INT_F_'+str(i)] + 0.68*df['TOR_F_'+str(i)] + 0.98*df['LS_' + str(i)] ,np.log(df['RH_'+str(i)] + 0.00000001) + 2.34*df['AIR_F_'+str(i)] + -0.66*df['INT_F_'+str(i)] + 0.68*df['TOR_F_'+str(i)] + 0.98*df['LS_' + str(i)]
    df['EXP_UTILITY_' + str(i)] = np.exp(df['UTILITY_'+str(i)])
    
df['LOGSUM'] = df['EXP_UTILITY_001'] + df['EXP_UTILITY_002'] + df['EXP_UTILITY_003'] + df['EXP_UTILITY_004'] + df['EXP_UTILITY_005'] + df['EXP_UTILITY_006'] + df['EXP_UTILITY_007'] + df['EXP_UTILITY_008'] + df['EXP_UTILITY_009'] + df['EXP_UTILITY_010'] + df['EXP_UTILITY_011'] + df['EXP_UTILITY_012'] + df['EXP_UTILITY_013'] + df['EXP_UTILITY_014'] + df['EXP_UTILITY_015'] + df['EXP_UTILITY_016'] + df['EXP_UTILITY_017'] + df['EXP_UTILITY_018'] + df['EXP_UTILITY_019'] + df['EXP_UTILITY_020'] + df['EXP_UTILITY_021'] + df['EXP_UTILITY_022'] + df['EXP_UTILITY_023'] + df['EXP_UTILITY_024'] + df['EXP_UTILITY_025'] + df['EXP_UTILITY_026'] + df['EXP_UTILITY_027'] + df['EXP_UTILITY_028'] + df['EXP_UTILITY_029'] + df['EXP_UTILITY_030'] + df['EXP_UTILITY_031'] + df['EXP_UTILITY_032'] + df['EXP_UTILITY_033'] + df['EXP_UTILITY_034'] + df['EXP_UTILITY_035'] + df['EXP_UTILITY_036'] + df['EXP_UTILITY_037'] + df['EXP_UTILITY_038'] + df['EXP_UTILITY_039'] + df['EXP_UTILITY_040'] + df['EXP_UTILITY_041'] + df['EXP_UTILITY_042'] + df['EXP_UTILITY_043'] + df['EXP_UTILITY_044'] + df['EXP_UTILITY_045'] + df['EXP_UTILITY_046'] + df['EXP_UTILITY_047'] + df['EXP_UTILITY_048'] + df['EXP_UTILITY_049'] + df['EXP_UTILITY_050'] + df['EXP_UTILITY_051'] + df['EXP_UTILITY_052'] + df['EXP_UTILITY_053'] + df['EXP_UTILITY_054'] + df['EXP_UTILITY_055'] + df['EXP_UTILITY_056'] + df['EXP_UTILITY_057'] + df['EXP_UTILITY_058'] + df['EXP_UTILITY_059'] + df['EXP_UTILITY_060'] + df['EXP_UTILITY_061'] + df['EXP_UTILITY_062'] + df['EXP_UTILITY_063'] + df['EXP_UTILITY_064'] + df['EXP_UTILITY_065'] + df['EXP_UTILITY_066'] + df['EXP_UTILITY_067'] + df['EXP_UTILITY_068'] + df['EXP_UTILITY_069'] + df['EXP_UTILITY_070'] + df['EXP_UTILITY_071'] + df['EXP_UTILITY_072'] + df['EXP_UTILITY_073'] + df['EXP_UTILITY_074'] + df['EXP_UTILITY_075'] + df['EXP_UTILITY_076'] + df['EXP_UTILITY_077'] + df['EXP_UTILITY_078'] + df['EXP_UTILITY_079'] + df['EXP_UTILITY_080'] + df['EXP_UTILITY_081'] + df['EXP_UTILITY_082'] + df['EXP_UTILITY_083'] + df['EXP_UTILITY_084'] + df['EXP_UTILITY_085'] + df['EXP_UTILITY_086'] + df['EXP_UTILITY_087'] + df['EXP_UTILITY_088'] + df['EXP_UTILITY_089'] + df['EXP_UTILITY_090'] + df['EXP_UTILITY_091'] + df['EXP_UTILITY_092'] + df['EXP_UTILITY_093'] + df['EXP_UTILITY_094'] + df['EXP_UTILITY_095'] + df['EXP_UTILITY_096'] + df['EXP_UTILITY_097'] + df['EXP_UTILITY_098'] + df['EXP_UTILITY_099'] + df['EXP_UTILITY_100'] + df['EXP_UTILITY_101'] + df['EXP_UTILITY_102'] + df['EXP_UTILITY_103'] + df['EXP_UTILITY_104'] + df['EXP_UTILITY_105'] + df['EXP_UTILITY_106'] + df['EXP_UTILITY_107'] + df['EXP_UTILITY_108'] + df['EXP_UTILITY_109'] + df['EXP_UTILITY_110'] + df['EXP_UTILITY_111'] + df['EXP_UTILITY_112'] + df['EXP_UTILITY_113'] + df['EXP_UTILITY_114'] + df['EXP_UTILITY_115'] + df['EXP_UTILITY_116'] + df['EXP_UTILITY_117'] + df['EXP_UTILITY_118'] + df['EXP_UTILITY_119'] + df['EXP_UTILITY_120'] + df['EXP_UTILITY_121'] + df['EXP_UTILITY_122'] + df['EXP_UTILITY_123'] + df['EXP_UTILITY_124'] + df['EXP_UTILITY_125'] + df['EXP_UTILITY_126'] + df['EXP_UTILITY_127'] + df['EXP_UTILITY_128'] + df['EXP_UTILITY_129'] + df['EXP_UTILITY_130'] + df['EXP_UTILITY_131'] + df['EXP_UTILITY_132'] + df['EXP_UTILITY_133'] + df['EXP_UTILITY_134'] + df['EXP_UTILITY_135'] + df['EXP_UTILITY_136'] + df['EXP_UTILITY_137'] + df['EXP_UTILITY_138'] + df['EXP_UTILITY_139'] + df['EXP_UTILITY_140'] + df['EXP_UTILITY_141'] + df['EXP_UTILITY_142'] + df['EXP_UTILITY_143'] + df['EXP_UTILITY_144'] + df['EXP_UTILITY_145'] + df['EXP_UTILITY_146'] + df['EXP_UTILITY_147'] + df['EXP_UTILITY_148'] + df['EXP_UTILITY_149'] + df['EXP_UTILITY_150'] + df['EXP_UTILITY_151'] + df['EXP_UTILITY_152'] + df['EXP_UTILITY_153'] + df['EXP_UTILITY_154'] + df['EXP_UTILITY_155'] + df['EXP_UTILITY_156'] + df['EXP_UTILITY_157'] + df['EXP_UTILITY_158'] + df['EXP_UTILITY_159'] + df['EXP_UTILITY_160'] + df['EXP_UTILITY_161'] + df['EXP_UTILITY_162'] + df['EXP_UTILITY_163'] + df['EXP_UTILITY_164'] + df['EXP_UTILITY_165'] + df['EXP_UTILITY_166'] + df['EXP_UTILITY_167'] + df['EXP_UTILITY_168'] + df['EXP_UTILITY_169'] + df['EXP_UTILITY_170'] + df['EXP_UTILITY_171'] + df['EXP_UTILITY_172'] + df['EXP_UTILITY_173'] + df['EXP_UTILITY_174'] + df['EXP_UTILITY_175'] + df['EXP_UTILITY_176'] + df['EXP_UTILITY_177'] + df['EXP_UTILITY_178'] + df['EXP_UTILITY_179'] + df['EXP_UTILITY_180'] + df['EXP_UTILITY_181'] + df['EXP_UTILITY_182'] + df['EXP_UTILITY_183'] + df['EXP_UTILITY_184'] + df['EXP_UTILITY_185'] + df['EXP_UTILITY_186'] + df['EXP_UTILITY_187'] + df['EXP_UTILITY_188'] + df['EXP_UTILITY_189'] + df['EXP_UTILITY_190'] + df['EXP_UTILITY_191'] + df['EXP_UTILITY_192'] + df['EXP_UTILITY_193'] + df['EXP_UTILITY_194'] + df['EXP_UTILITY_195'] + df['EXP_UTILITY_196'] + df['EXP_UTILITY_197'] + df['EXP_UTILITY_198'] + df['EXP_UTILITY_199'] + df['EXP_UTILITY_200'] + df['EXP_UTILITY_201'] + df['EXP_UTILITY_202'] + df['EXP_UTILITY_203'] + df['EXP_UTILITY_204'] + df['EXP_UTILITY_205'] + df['EXP_UTILITY_206'] + df['EXP_UTILITY_207'] + df['EXP_UTILITY_208'] + df['EXP_UTILITY_209'] + df['EXP_UTILITY_210'] + df['EXP_UTILITY_211'] + df['EXP_UTILITY_212'] + df['EXP_UTILITY_213'] + df['EXP_UTILITY_214'] + df['EXP_UTILITY_215'] + df['EXP_UTILITY_216'] + df['EXP_UTILITY_217'] + df['EXP_UTILITY_218'] + df['EXP_UTILITY_219'] + df['EXP_UTILITY_220'] + df['EXP_UTILITY_221'] + df['EXP_UTILITY_222'] + df['EXP_UTILITY_223'] + df['EXP_UTILITY_224'] + df['EXP_UTILITY_225'] + df['EXP_UTILITY_226'] + df['EXP_UTILITY_227'] + df['EXP_UTILITY_228'] + df['EXP_UTILITY_229'] + df['EXP_UTILITY_230'] + df['EXP_UTILITY_231'] + df['EXP_UTILITY_232'] + df['EXP_UTILITY_233'] + df['EXP_UTILITY_234'] + df['EXP_UTILITY_235'] + df['EXP_UTILITY_236'] + df['EXP_UTILITY_237'] + df['EXP_UTILITY_238'] + df['EXP_UTILITY_239'] + df['EXP_UTILITY_240'] + df['EXP_UTILITY_241'] + df['EXP_UTILITY_242'] + df['EXP_UTILITY_243'] + df['EXP_UTILITY_244'] + df['EXP_UTILITY_245'] + df['EXP_UTILITY_246'] + df['EXP_UTILITY_247'] + df['EXP_UTILITY_248'] + df['EXP_UTILITY_249'] + df['EXP_UTILITY_250'] + df['EXP_UTILITY_251'] + df['EXP_UTILITY_252'] + df['EXP_UTILITY_253'] + df['EXP_UTILITY_254'] + df['EXP_UTILITY_255'] + df['EXP_UTILITY_256'] + df['EXP_UTILITY_257'] + df['EXP_UTILITY_258'] + df['EXP_UTILITY_259'] + df['EXP_UTILITY_260'] + df['EXP_UTILITY_261'] + df['EXP_UTILITY_262'] + df['EXP_UTILITY_263'] + df['EXP_UTILITY_264'] + df['EXP_UTILITY_265'] + df['EXP_UTILITY_266'] + df['EXP_UTILITY_267'] + df['EXP_UTILITY_268'] + df['EXP_UTILITY_269'] + df['EXP_UTILITY_270'] + df['EXP_UTILITY_271'] + df['EXP_UTILITY_272'] + df['EXP_UTILITY_273'] + df['EXP_UTILITY_274'] + df['EXP_UTILITY_275'] + df['EXP_UTILITY_276'] + df['EXP_UTILITY_277'] + df['EXP_UTILITY_278'] + df['EXP_UTILITY_279'] + df['EXP_UTILITY_280'] + df['EXP_UTILITY_281'] + df['EXP_UTILITY_282'] + df['EXP_UTILITY_283'] + df['EXP_UTILITY_284'] + df['EXP_UTILITY_285'] + df['EXP_UTILITY_286'] + df['EXP_UTILITY_287'] + df['EXP_UTILITY_288'] + df['EXP_UTILITY_289'] + df['EXP_UTILITY_290'] + df['EXP_UTILITY_291'] + df['EXP_UTILITY_292'] + df['EXP_UTILITY_293'] + df['EXP_UTILITY_294'] + df['EXP_UTILITY_295'] + df['EXP_UTILITY_296'] + df['EXP_UTILITY_297'] + df['EXP_UTILITY_298'] + df['EXP_UTILITY_299'] + df['EXP_UTILITY_300'] + df['EXP_UTILITY_301'] + df['EXP_UTILITY_302'] + df['EXP_UTILITY_303'] + df['EXP_UTILITY_304'] + df['EXP_UTILITY_305'] + df['EXP_UTILITY_306'] + df['EXP_UTILITY_307'] + df['EXP_UTILITY_308'] + df['EXP_UTILITY_309'] + df['EXP_UTILITY_310'] + df['EXP_UTILITY_311'] + df['EXP_UTILITY_312'] + df['EXP_UTILITY_313'] + df['EXP_UTILITY_314'] + df['EXP_UTILITY_315'] + df['EXP_UTILITY_316'] + df['EXP_UTILITY_317'] + df['EXP_UTILITY_318'] + df['EXP_UTILITY_319'] + df['EXP_UTILITY_320'] + df['EXP_UTILITY_321'] + df['EXP_UTILITY_322'] + df['EXP_UTILITY_323'] + df['EXP_UTILITY_324'] + df['EXP_UTILITY_325'] + df['EXP_UTILITY_326'] + df['EXP_UTILITY_327'] + df['EXP_UTILITY_328'] + df['EXP_UTILITY_329'] + df['EXP_UTILITY_330'] + df['EXP_UTILITY_331'] + df['EXP_UTILITY_332'] + df['EXP_UTILITY_333'] + df['EXP_UTILITY_334'] + df['EXP_UTILITY_335'] + df['EXP_UTILITY_336'] + df['EXP_UTILITY_337'] + df['EXP_UTILITY_338'] + df['EXP_UTILITY_339'] + df['EXP_UTILITY_340'] + df['EXP_UTILITY_341'] + df['EXP_UTILITY_342'] + df['EXP_UTILITY_343'] + df['EXP_UTILITY_344'] + df['EXP_UTILITY_345'] + df['EXP_UTILITY_346'] + df['EXP_UTILITY_347'] + df['EXP_UTILITY_348'] + df['EXP_UTILITY_349'] + df['EXP_UTILITY_350'] + df['EXP_UTILITY_351'] + df['EXP_UTILITY_352'] + df['EXP_UTILITY_353'] + df['EXP_UTILITY_354'] + df['EXP_UTILITY_355'] + df['EXP_UTILITY_356'] + df['EXP_UTILITY_357'] + df['EXP_UTILITY_358'] + df['EXP_UTILITY_359'] + df['EXP_UTILITY_360'] + df['EXP_UTILITY_361'] + df['EXP_UTILITY_362'] + df['EXP_UTILITY_363'] + df['EXP_UTILITY_364'] + df['EXP_UTILITY_365'] + df['EXP_UTILITY_366'] + df['EXP_UTILITY_367'] +df['EXP_UTILITY_368'] + df['EXP_UTILITY_369'] + df['EXP_UTILITY_370'] + df['EXP_UTILITY_371'] + df['EXP_UTILITY_372'] + df['EXP_UTILITY_373'] + df['EXP_UTILITY_374'] + df['EXP_UTILITY_375'] + df['EXP_UTILITY_376'] + df['EXP_UTILITY_377'] + df['EXP_UTILITY_378'] + df['EXP_UTILITY_379'] + df['EXP_UTILITY_380'] + df['EXP_UTILITY_381'] + df['EXP_UTILITY_382'] + df['EXP_UTILITY_383'] + df['EXP_UTILITY_384'] + df['EXP_UTILITY_385'] + df['EXP_UTILITY_386'] + df['EXP_UTILITY_387'] + df['EXP_UTILITY_388'] + df['EXP_UTILITY_389'] + df['EXP_UTILITY_390'] + df['EXP_UTILITY_391'] + df['EXP_UTILITY_392'] + df['EXP_UTILITY_393'] + df['EXP_UTILITY_394'] + df['EXP_UTILITY_395'] + df['EXP_UTILITY_396'] + df['EXP_UTILITY_397'] + df['EXP_UTILITY_398'] +df['EXP_UTILITY_399'] + df['EXP_UTILITY_400'] + df['EXP_UTILITY_401'] + df['EXP_UTILITY_402'] + df['EXP_UTILITY_403'] + df['EXP_UTILITY_404'] + df['EXP_UTILITY_405'] + df['EXP_UTILITY_406'] + df['EXP_UTILITY_407'] + df['EXP_UTILITY_408'] + df['EXP_UTILITY_409'] + df['EXP_UTILITY_410'] + df['EXP_UTILITY_411'] + df['EXP_UTILITY_412'] + df['EXP_UTILITY_413'] + df['EXP_UTILITY_414'] + df['EXP_UTILITY_415'] + df['EXP_UTILITY_416'] + df['EXP_UTILITY_417'] + df['EXP_UTILITY_418'] + df['EXP_UTILITY_419'] + df['EXP_UTILITY_420'] + df['EXP_UTILITY_421'] + df['EXP_UTILITY_422'] + df['EXP_UTILITY_423'] + df['EXP_UTILITY_424'] + df['EXP_UTILITY_425'] + df['EXP_UTILITY_426'] + df['EXP_UTILITY_427'] + df['EXP_UTILITY_428'] + df['EXP_UTILITY_429'] + df['EXP_UTILITY_430'] + df['EXP_UTILITY_431'] + df['EXP_UTILITY_432'] + df['EXP_UTILITY_433'] + df['EXP_UTILITY_434'] + df['EXP_UTILITY_435'] + df['EXP_UTILITY_436'] + df['EXP_UTILITY_437'] + df['EXP_UTILITY_438'] + df['EXP_UTILITY_439'] + df['EXP_UTILITY_440'] + df['EXP_UTILITY_441'] + df['EXP_UTILITY_442'] + df['EXP_UTILITY_443'] + df['EXP_UTILITY_444'] + df['EXP_UTILITY_445'] + df['EXP_UTILITY_446'] + df['EXP_UTILITY_447'] + df['EXP_UTILITY_448'] + df['EXP_UTILITY_449'] + df['EXP_UTILITY_450'] + df['EXP_UTILITY_451'] + df['EXP_UTILITY_452'] + df['EXP_UTILITY_453'] + df['EXP_UTILITY_454'] + df['EXP_UTILITY_455'] + df['EXP_UTILITY_456'] + df['EXP_UTILITY_457'] + df['EXP_UTILITY_458'] + df['EXP_UTILITY_459'] + df['EXP_UTILITY_460'] + df['EXP_UTILITY_461'] + df['EXP_UTILITY_462'] + df['EXP_UTILITY_463'] + df['EXP_UTILITY_464'] + df['EXP_UTILITY_465'] + df['EXP_UTILITY_466'] + df['EXP_UTILITY_467'] + df['EXP_UTILITY_468'] + df['EXP_UTILITY_469'] + df['EXP_UTILITY_470'] + df['EXP_UTILITY_471'] + df['EXP_UTILITY_472'] + df['EXP_UTILITY_473'] + df['EXP_UTILITY_474'] + df['EXP_UTILITY_475'] + df['EXP_UTILITY_476'] + df['EXP_UTILITY_477'] + df['EXP_UTILITY_478'] + df['EXP_UTILITY_479'] + df['EXP_UTILITY_480'] + df['EXP_UTILITY_481'] + df['EXP_UTILITY_482'] + df['EXP_UTILITY_483'] + df['EXP_UTILITY_484'] + df['EXP_UTILITY_485'] + df['EXP_UTILITY_486'] + df['EXP_UTILITY_487'] + df['EXP_UTILITY_488'] + df['EXP_UTILITY_489'] + df['EXP_UTILITY_490'] + df['EXP_UTILITY_491'] + df['EXP_UTILITY_492'] + df['EXP_UTILITY_493'] + df['EXP_UTILITY_494'] + df['EXP_UTILITY_495'] + df['EXP_UTILITY_496'] + df['EXP_UTILITY_497'] + df['EXP_UTILITY_498'] + df['EXP_UTILITY_499'] + df['EXP_UTILITY_500'] + df['EXP_UTILITY_501'] + df['EXP_UTILITY_502'] + df['EXP_UTILITY_503'] + df['EXP_UTILITY_504'] + df['EXP_UTILITY_505'] + df['EXP_UTILITY_506'] + df['EXP_UTILITY_507'] + df['EXP_UTILITY_508'] + df['EXP_UTILITY_509'] + df['EXP_UTILITY_510'] + df['EXP_UTILITY_511'] + df['EXP_UTILITY_512'] + df['EXP_UTILITY_513'] + df['EXP_UTILITY_514'] + df['EXP_UTILITY_515'] + df['EXP_UTILITY_516'] + df['EXP_UTILITY_517'] + df['EXP_UTILITY_518'] + df['EXP_UTILITY_519'] + df['EXP_UTILITY_520'] + df['EXP_UTILITY_521'] + df['EXP_UTILITY_522'] + df['EXP_UTILITY_523'] + df['EXP_UTILITY_524'] + df['EXP_UTILITY_525'] + df['EXP_UTILITY_526'] + df['EXP_UTILITY_527'] + df['EXP_UTILITY_528'] + df['EXP_UTILITY_529'] + df['EXP_UTILITY_530'] + df['EXP_UTILITY_531'] + df['EXP_UTILITY_532'] + df['EXP_UTILITY_533'] + df['EXP_UTILITY_534'] + df['EXP_UTILITY_535'] + df['EXP_UTILITY_536'] + df['EXP_UTILITY_537'] + df['EXP_UTILITY_538'] + df['EXP_UTILITY_539'] + df['EXP_UTILITY_540'] + df['EXP_UTILITY_541'] + df['EXP_UTILITY_542'] + df['EXP_UTILITY_543'] + df['EXP_UTILITY_544'] + df['EXP_UTILITY_545'] + df['EXP_UTILITY_546'] + df['EXP_UTILITY_547'] + df['EXP_UTILITY_548'] + df['EXP_UTILITY_549'] + df['EXP_UTILITY_550'] + df['EXP_UTILITY_551'] + df['EXP_UTILITY_552'] + df['EXP_UTILITY_553'] + df['EXP_UTILITY_554'] + df['EXP_UTILITY_555'] + df['EXP_UTILITY_556'] + df['EXP_UTILITY_557'] + df['EXP_UTILITY_558'] + df['EXP_UTILITY_559'] + df['EXP_UTILITY_560'] + df['EXP_UTILITY_561'] + df['EXP_UTILITY_562'] + df['EXP_UTILITY_563'] + df['EXP_UTILITY_564'] + df['EXP_UTILITY_565'] + df['EXP_UTILITY_566'] + df['EXP_UTILITY_567'] + df['EXP_UTILITY_568'] + df['EXP_UTILITY_569'] + df['EXP_UTILITY_570'] + df['EXP_UTILITY_571'] + df['EXP_UTILITY_572'] + df['EXP_UTILITY_573'] + df['EXP_UTILITY_574'] + df['EXP_UTILITY_575'] + df['EXP_UTILITY_576'] + df['EXP_UTILITY_577'] + df['EXP_UTILITY_578'] + df['EXP_UTILITY_579'] + df['EXP_UTILITY_580'] + df['EXP_UTILITY_581'] + df['EXP_UTILITY_582'] + df['EXP_UTILITY_583'] + df['EXP_UTILITY_584'] + df['EXP_UTILITY_585'] + df['EXP_UTILITY_586'] + df['EXP_UTILITY_587'] + df['EXP_UTILITY_588'] + df['EXP_UTILITY_589'] + df['EXP_UTILITY_590'] + df['EXP_UTILITY_591'] + df['EXP_UTILITY_592'] + df['EXP_UTILITY_593'] + df['EXP_UTILITY_594'] + df['EXP_UTILITY_595'] + df['EXP_UTILITY_596'] + df['EXP_UTILITY_597'] + df['EXP_UTILITY_598'] + df['EXP_UTILITY_599'] + df['EXP_UTILITY_600'] + df['EXP_UTILITY_601'] + df['EXP_UTILITY_602'] + df['EXP_UTILITY_603'] + df['EXP_UTILITY_604'] + df['EXP_UTILITY_605'] + df['EXP_UTILITY_606'] + df['EXP_UTILITY_607'] + df['EXP_UTILITY_608'] + df['EXP_UTILITY_609'] + df['EXP_UTILITY_610'] + df['EXP_UTILITY_611'] + df['EXP_UTILITY_612'] + df['EXP_UTILITY_613'] + df['EXP_UTILITY_614'] + df['EXP_UTILITY_615'] + df['EXP_UTILITY_616'] + df['EXP_UTILITY_617'] + df['EXP_UTILITY_618'] + df['EXP_UTILITY_619'] + df['EXP_UTILITY_620'] + df['EXP_UTILITY_621'] + df['EXP_UTILITY_622'] + df['EXP_UTILITY_623'] + df['EXP_UTILITY_624'] + df['EXP_UTILITY_625'] + df['EXP_UTILITY_626'] + df['EXP_UTILITY_627'] + df['EXP_UTILITY_628'] + df['EXP_UTILITY_629'] + df['EXP_UTILITY_630'] + df['EXP_UTILITY_631'] + df['EXP_UTILITY_632'] + df['EXP_UTILITY_633'] + df['EXP_UTILITY_634'] + df['EXP_UTILITY_635'] + df['EXP_UTILITY_636'] + df['EXP_UTILITY_637'] + df['EXP_UTILITY_638'] + df['EXP_UTILITY_639'] + df['EXP_UTILITY_640'] + df['EXP_UTILITY_641'] + df['EXP_UTILITY_642'] + df['EXP_UTILITY_643'] + df['EXP_UTILITY_644'] + df['EXP_UTILITY_645'] + df['EXP_UTILITY_646'] + df['EXP_UTILITY_647'] + df['EXP_UTILITY_648'] + df['EXP_UTILITY_649'] + df['EXP_UTILITY_650'] + df['EXP_UTILITY_651'] + df['EXP_UTILITY_652'] + df['EXP_UTILITY_653'] + df['EXP_UTILITY_654'] + df['EXP_UTILITY_655'] + df['EXP_UTILITY_656'] + df['EXP_UTILITY_657'] + df['EXP_UTILITY_658'] + df['EXP_UTILITY_659'] + df['EXP_UTILITY_660'] + df['EXP_UTILITY_661'] + df['EXP_UTILITY_662'] + df['EXP_UTILITY_663'] + df['EXP_UTILITY_664'] + df['EXP_UTILITY_665'] + df['EXP_UTILITY_666'] + df['EXP_UTILITY_667'] + df['EXP_UTILITY_668'] + df['EXP_UTILITY_669'] + df['EXP_UTILITY_670'] + df['EXP_UTILITY_671'] + df['EXP_UTILITY_672'] + df['EXP_UTILITY_673'] + df['EXP_UTILITY_674'] + df['EXP_UTILITY_675'] + df['EXP_UTILITY_676'] + df['EXP_UTILITY_677'] + df['EXP_UTILITY_678'] + df['EXP_UTILITY_679'] + df['EXP_UTILITY_680'] + df['EXP_UTILITY_681'] + df['EXP_UTILITY_682'] + df['EXP_UTILITY_683'] + df['EXP_UTILITY_684'] + df['EXP_UTILITY_685'] + df['EXP_UTILITY_686'] + df['EXP_UTILITY_687'] + df['EXP_UTILITY_688'] + df['EXP_UTILITY_689'] + df['EXP_UTILITY_690'] + df['EXP_UTILITY_691'] + df['EXP_UTILITY_692'] + df['EXP_UTILITY_693'] + df['EXP_UTILITY_694'] + df['EXP_UTILITY_695'] + df['EXP_UTILITY_696'] + df['EXP_UTILITY_697'] + df['EXP_UTILITY_698'] + df['EXP_UTILITY_699'] + df['EXP_UTILITY_700'] + df['EXP_UTILITY_701'] + df['EXP_UTILITY_702'] + df['EXP_UTILITY_703'] + df['EXP_UTILITY_704'] + df['EXP_UTILITY_705'] + df['EXP_UTILITY_706'] + df['EXP_UTILITY_707'] + df['EXP_UTILITY_708'] + df['EXP_UTILITY_709'] + df['EXP_UTILITY_710'] + df['EXP_UTILITY_711'] + df['EXP_UTILITY_712'] + df['EXP_UTILITY_713'] + df['EXP_UTILITY_714'] + df['EXP_UTILITY_715'] + df['EXP_UTILITY_716'] + df['EXP_UTILITY_717'] + df['EXP_UTILITY_718'] + df['EXP_UTILITY_719'] + df['EXP_UTILITY_720'] + df['EXP_UTILITY_721'] + df['EXP_UTILITY_722'] + df['EXP_UTILITY_723'] + df['EXP_UTILITY_724'] + df['EXP_UTILITY_725'] + df['EXP_UTILITY_726'] + df['EXP_UTILITY_727'] + df['EXP_UTILITY_728'] + df['EXP_UTILITY_729'] + df['EXP_UTILITY_730'] + df['EXP_UTILITY_731'] + df['EXP_UTILITY_732'] + df['EXP_UTILITY_733'] + df['EXP_UTILITY_734'] + df['EXP_UTILITY_735'] + df['EXP_UTILITY_736'] + df['EXP_UTILITY_737'] + df['EXP_UTILITY_738'] + df['EXP_UTILITY_739'] + df['EXP_UTILITY_740'] + df['EXP_UTILITY_741'] + df['EXP_UTILITY_742'] + df['EXP_UTILITY_743'] + df['EXP_UTILITY_744'] + df['EXP_UTILITY_745'] + df['EXP_UTILITY_746'] + df['EXP_UTILITY_747'] + df['EXP_UTILITY_748'] + df['EXP_UTILITY_749'] + df['EXP_UTILITY_750'] + df['EXP_UTILITY_751'] + df['EXP_UTILITY_752'] + df['EXP_UTILITY_753'] + df['EXP_UTILITY_754'] + df['EXP_UTILITY_755'] + df['EXP_UTILITY_756'] + df['EXP_UTILITY_757'] + df['EXP_UTILITY_758'] + df['EXP_UTILITY_759'] + df['EXP_UTILITY_760'] + df['EXP_UTILITY_761'] + df['EXP_UTILITY_762'] + df['EXP_UTILITY_763'] + df['EXP_UTILITY_764'] + df['EXP_UTILITY_765'] + df['EXP_UTILITY_766'] + df['EXP_UTILITY_767'] + df['EXP_UTILITY_768'] + df['EXP_UTILITY_769'] + df['EXP_UTILITY_770'] + df['EXP_UTILITY_771'] + df['EXP_UTILITY_772'] + df['EXP_UTILITY_773'] + df['EXP_UTILITY_774'] + df['EXP_UTILITY_775'] + df['EXP_UTILITY_776'] + df['EXP_UTILITY_777'] + df['EXP_UTILITY_778'] + df['EXP_UTILITY_779'] + df['EXP_UTILITY_780'] + df['EXP_UTILITY_781'] + df['EXP_UTILITY_782'] + df['EXP_UTILITY_783'] + df['EXP_UTILITY_784'] + df['EXP_UTILITY_785'] + df['EXP_UTILITY_786'] + df['EXP_UTILITY_787'] + df['EXP_UTILITY_788'] + df['EXP_UTILITY_789'] + df['EXP_UTILITY_790'] + df['EXP_UTILITY_791'] + df['EXP_UTILITY_792'] + df['EXP_UTILITY_793'] + df['EXP_UTILITY_794'] + df['EXP_UTILITY_795'] + df['EXP_UTILITY_796'] + df['EXP_UTILITY_797'] + df['EXP_UTILITY_798'] + df['EXP_UTILITY_799'] + df['EXP_UTILITY_800'] + df['EXP_UTILITY_801']
# Out:
# Working on ALT 1
# C:\Users\ramu225\Anaconda3\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Working on ALT 2
# Working on ALT 3
# Working on ALT 4
# Working on ALT 5
# Working on ALT 6
# Working on ALT 7
# Working on ALT 8
# Working on ALT 9
# Working on ALT 10
# Working on ALT 11
# Working on ALT 12
# Working on ALT 13
# Working on ALT 14
# Working on ALT 15
# Working on ALT 16
# Working on ALT 17
# Working on ALT 18
# Working on ALT 19
# Working on ALT 20
# Working on ALT 21
# Working on ALT 22
# Working on ALT 23
# Working on ALT 24
# Working on ALT 25
# Working on ALT 26
# Working on ALT 27
# Working on ALT 28
# Working on ALT 29
# Working on ALT 30
# Working on ALT 31
# Working on ALT 32
# Working on ALT 33
# Working on ALT 34
# Working on ALT 35
# Working on ALT 36
# Working on ALT 37
# Working on ALT 38
# Working on ALT 39
# Working on ALT 40
# Working on ALT 41
# ...

# %%
# Out:
# 7.38905609893065

# %%
np.log(df['RH_002']).mean()
# Out:
# -inf

# %%
np.log(df['RH_003']).mean()
# Out:
# 0.9307284319803705

# %%
for i in range(1,802):
    print('Working on ALT ' + str(i))
    i = "{:03d}".format(i)
    print(df['RH_' + str(i)].min())
    print(np.log(df['RH_' + str(i)]).mean())
# Out:
# Working on ALT 1
# 0.0
# -inf
# Working on ALT 2
# 0.0
# -inf
# Working on ALT 3
# 1.0
# 0.9307284319803705
# Working on ALT 4
# 1.0
# 0.6555446387248381
# Working on ALT 5
# 7.2
# 2.3067003456883026
# Working on ALT 6
# 1.75
# 0.9902435668762392
# Working on ALT 7
# 0.0
# -inf
# Working on ALT 8
# 0.0
# -inf
# Working on ALT 9
# 0.0
# -inf
# Working on ALT 10
# 0.0
# -inf
# Working on ALT 11
# 1.0
# 0.48790452859999567
# Working on ALT 12
# 1.6
# 1.022992372722872
# Working on ALT 13
# 0.0
# -inf
# Working on ALT 14
# 0.0
# -inf
# Working on ALT 15
# 0.0
# -inf
# Working on ALT 16
# 0.0
# -inf
# Working on ALT 17
# 4.2
# 1.7945049073626902
# Working on ALT 18
# 2.2
# 1.4969635876215142
# Working on ALT 19
# 1.0
# 0.46452141426060145
# Working on ALT 20
# 1.6
# 0.8766814619979667
# Working on ALT 21
# 0.0
# -inf
# Working on ALT 22
# 0.0
# -inf
# Working on ALT 23
# 2.75
# 1.244714501502999
# Working on ALT 24
# 2.0
# 1.1078182788171131
# Working on ALT 25
# 2.0
# 0.9750521753216412
# ...

# %%
    df['UTILITY_' + str(i)] = 2.34*df['AIR_F_'+str(i)] + -0.66*df['INT_F_'+str(i)] + 0.68*df['TOR_F_'+str(i)] + 0.98*df['LS_' + str(i)]
