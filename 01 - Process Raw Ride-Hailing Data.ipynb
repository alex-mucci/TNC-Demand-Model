# %%
import pandas as pd
import numpy as np
import sys 
import datetime
import os
import matplotlib as plt

# %matplotlib inline

# %%
agg = {'Fare':'mean','Trip Total':'mean','Trip Miles':'sum','Trips Pooled':'sum','PRIVATE_TRIPS':'sum','SHARED_TRIPS':'sum','TRIPS':'sum'}

# %%
def clean_float_cols(x):
    x = x.replace(',','')
    x = float(x)
    
    return x

# %%
def processRawData(infile, outfile):
        """
        Reads data, cleans it, processes it, and writes it to an HDF5 file.
        
        infile  - infile name, raw CSV format
        outfile - output file name, h5 format
        outkey = name of table in output h5 file
        """
        
        print(datetime.datetime.now().ctime(), 'Converting raw data in file: ', infile)
        
        # set up the reader
        reader = pd.read_csv(infile,  
                         iterator = True, 
                         sep = ',', 
        parse_dates = ['Trip Start Timestamp','Trip End Timestamp'], infer_datetime_format = True, chunksize= 25000)

        # establish the writer and clear any table with that file name
        store = pd.HDFStore(outfile)

        # iterate through chunk by chunk so the computer doesn't run out of memory
        rowsRead    = 0
        rowsWritten_weekday = 0
        rowsWritten_weekend = 0
        
        for chunk in reader:   

            rowsRead += len(chunk)
            
            #convert columns from a string because it caused problems
            convert_cols = ['Trip Seconds','Trip Miles', 'Pickup Census Tract', 'Dropoff Census Tract','Fare', 
                            'Tip','Additional Charges', 'Trip Total', 'Trips Pooled']
        
            for column in convert_cols:
                chunk[column] = chunk[column].astype(str).apply(lambda x: x.replace(',',''))
                chunk[column] = chunk[column].astype(float)
           
            chunk['YEAR'], chunk['MONTH'], chunk['DOW'], chunk['HOUR'] = chunk['Trip Start Timestamp'].dt.year, chunk['Trip Start Timestamp'].dt.month, chunk['Trip Start Timestamp'].dt.weekday, chunk['Trip Start Timestamp'].dt.hour
            
            chunk_weekday = chunk[chunk['DOW'].isin([0,1,2,3,4])]
            chunk_weekend = chunk[chunk['DOW'].isin([5,6])]

            chunk_weekday_1 = chunk_weekday[chunk_weekday['HOUR'].isin([22,23,24,1,2,3,4,5])]
            chunk_weekday_2 = chunk_weekday[chunk_weekday['HOUR'].isin([6,7,8])]
            chunk_weekday_3 = chunk_weekday[chunk_weekday['HOUR'].isin([9,10,11,12,13,14,15])]
            chunk_weekday_4 = chunk_weekday[chunk_weekday['HOUR'].isin([16,17,18])]
            chunk_weekday_5 = chunk_weekday[chunk_weekday['HOUR'].isin([19,20,21])]

            chunk_weekend_1 = chunk_weekend[chunk_weekend['HOUR'].isin([22,23,24,1,2,3,4,5])]
            chunk_weekend_2 = chunk_weekend[chunk_weekend['HOUR'].isin([6,7,8])]
            chunk_weekend_3 = chunk_weekend[chunk_weekend['HOUR'].isin([9,10,11,12,13,14,15])]
            chunk_weekend_4 = chunk_weekend[chunk_weekend['HOUR'].isin([16,17,18])]
            chunk_weekend_5 = chunk_weekend[chunk_weekend['HOUR'].isin([19,20,21])]

            
            
            # write the data
            store.append('Weekday_1', chunk_weekday_1, data_columns = True)
            store.append('Weekday_2', chunk_weekday_2, data_columns = True)
            store.append('Weekday_3', chunk_weekday_3, data_columns = True)
            store.append('Weekday_4', chunk_weekday_4, data_columns = True)
            store.append('Weekday_5', chunk_weekday_5, data_columns = True)


            store.append('Weekend_1', chunk_weekend_1, data_columns = True)
            store.append('Weekend_2', chunk_weekend_2, data_columns = True)
            store.append('Weekend_3', chunk_weekend_3, data_columns = True)
            store.append('Weekend_4', chunk_weekend_4, data_columns = True)
            store.append('Weekend_5', chunk_weekend_5, data_columns = True)


            rowsWritten_weekday += len(chunk_weekday)
            rowsWritten_weekend += len(chunk_weekend)

            print ('Read %i rows and kept %i rows in weekday TNC table' % (rowsRead, rowsWritten_weekday))
            print ('kept ' + str(rowsWritten_weekend) + ' rows in weekend TNC table')

        store.close()
        print('Complete!!!')

# %%
#create the shared TNC trip h5 table
processRawData('D:/TNC-Demand-Model/Inputs/Chicago Ride-Hailing/Transportation_Network_Providers_-_Trips.csv', 'D:/TNC-Demand-Model/Inputs/Chicago Ride-Hailing/Chicago_TNC_Trips_20.H5')
# Out:
# Thu Jan 14 09:33:02 2021 Converting raw data in file:  D:/TNC-Demand-Model/Inputs/Chicago Ride-Hailing/Transportation_Network_Providers_-_Trips.csv
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Trip ID'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Start Timestamp'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Trip End Timestamp'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Seconds'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Miles'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Pickup Census Tract'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Dropoff Census Tract'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Pickup Community Area'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Dropoff Community Area'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Additional Charges'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Total'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Shared Trip Authorized'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Trips Pooled'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Pickup Centroid Latitude'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Pickup Centroid Longitude'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Pickup Centroid Location'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Dropoff Centroid Latitude'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Dropoff Centroid Longitude'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Dropoff Centroid Location'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip ID_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip ID_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip ID_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Start Timestamp_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Start Timestamp_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Start Timestamp_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip End Timestamp_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip End Timestamp_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip End Timestamp_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Seconds_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Seconds_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Seconds_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Miles_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Miles_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Miles_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Pickup Census Tract_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Pickup Census Tract_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Pickup Census Tract_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Dropoff Census Tract_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Dropoff Census Tract_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Dropoff Census Tract_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Pickup Community Area_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Pickup Community Area_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Pickup Community Area_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Dropoff Community Area_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Dropoff Community Area_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Dropoff Community Area_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Additional Charges_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Additional Charges_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Additional Charges_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Total_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Total_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trip Total_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Shared Trip Authorized_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Shared Trip Authorized_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Shared Trip Authorized_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trips Pooled_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trips Pooled_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Trips Pooled_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Pickup Centroid Latitude_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Pickup Centroid Latitude_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Pickup Centroid Latitude_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Pickup Centroid Longitude_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Pickup Centroid Longitude_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Pickup Centroid Longitude_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Pickup Centroid Location_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Pickup Centroid Location_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Pickup Centroid Location_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Dropoff Centroid Latitude_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Dropoff Centroid Latitude_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Dropoff Centroid Latitude_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Dropoff Centroid Longitude_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Dropoff Centroid Longitude_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Dropoff Centroid Longitude_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Dropoff Centroid Location_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Dropoff Centroid Location_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\transportlab\anaconda3\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Dropoff Centroid Location_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# Read 25000 rows and kept 16883 rows in weekday TNC table
# kept 8117 rows in weekend TNC table
# Read 50000 rows and kept 33610 rows in weekday TNC table
# kept 16390 rows in weekend TNC table
# Read 75000 rows and kept 50406 rows in weekday TNC table
# kept 24594 rows in weekend TNC table
# Read 100000 rows and kept 67205 rows in weekday TNC table
# kept 32795 rows in weekend TNC table
# Read 125000 rows and kept 84109 rows in weekday TNC table
# kept 40891 rows in weekend TNC table
# Read 150000 rows and kept 100880 rows in weekday TNC table
# kept 49120 rows in weekend TNC table
# Read 175000 rows and kept 117666 rows in weekday TNC table
# kept 57334 rows in weekend TNC table
# Read 200000 rows and kept 134464 rows in weekday TNC table
# kept 65536 rows in weekend TNC table
# Read 225000 rows and kept 151296 rows in weekday TNC table
# kept 73704 rows in weekend TNC table
# Read 250000 rows and kept 167975 rows in weekday TNC table
# kept 82025 rows in weekend TNC table
# Read 275000 rows and kept 184714 rows in weekday TNC table
# kept 90286 rows in weekend TNC table
# Read 300000 rows and kept 201541 rows in weekday TNC table
# kept 98459 rows in weekend TNC table
# Read 325000 rows and kept 218447 rows in weekday TNC table
# kept 106553 rows in weekend TNC table
# Read 350000 rows and kept 235189 rows in weekday TNC table
# kept 114811 rows in weekend TNC table
# Read 375000 rows and kept 252078 rows in weekday TNC table
# kept 122922 rows in weekend TNC table
# Read 400000 rows and kept 268946 rows in weekday TNC table
# kept 131054 rows in weekend TNC table
# Read 425000 rows and kept 285811 rows in weekday TNC table
# kept 139189 rows in weekend TNC table
# Read 450000 rows and kept 302647 rows in weekday TNC table
# kept 147353 rows in weekend TNC table
# Read 475000 rows and kept 319383 rows in weekday TNC table
# kept 155617 rows in weekend TNC table
# Read 500000 rows and kept 336228 rows in weekday TNC table
# kept 163772 rows in weekend TNC table
# Read 525000 rows and kept 353054 rows in weekday TNC table
# kept 171946 rows in weekend TNC table
# Read 550000 rows and kept 369800 rows in weekday TNC table
# kept 180200 rows in weekend TNC table
# Read 575000 rows and kept 386529 rows in weekday TNC table
# kept 188471 rows in weekend TNC table
# Read 600000 rows and kept 403407 rows in weekday TNC table
# kept 196593 rows in weekend TNC table
# Read 625000 rows and kept 420207 rows in weekday TNC table
# kept 204793 rows in weekend TNC table
# Read 650000 rows and kept 436925 rows in weekday TNC table
# kept 213075 rows in weekend TNC table
# Read 675000 rows and kept 453613 rows in weekday TNC table
# kept 221387 rows in weekend TNC table
# Read 700000 rows and kept 470557 rows in weekday TNC table
# kept 229443 rows in weekend TNC table
# Read 725000 rows and kept 487417 rows in weekday TNC table
# kept 237583 rows in weekend TNC table
# Read 750000 rows and kept 504124 rows in weekday TNC table
# kept 245876 rows in weekend TNC table
# Read 775000 rows and kept 520928 rows in weekday TNC table
# kept 254072 rows in weekend TNC table
# Read 800000 rows and kept 537776 rows in weekday TNC table
# kept 262224 rows in weekend TNC table
# Read 825000 rows and kept 554639 rows in weekday TNC table
# kept 270361 rows in weekend TNC table
# Read 850000 rows and kept 571327 rows in weekday TNC table
# kept 278673 rows in weekend TNC table
# Read 875000 rows and kept 588082 rows in weekday TNC table
# kept 286918 rows in weekend TNC table
# Read 900000 rows and kept 604857 rows in weekday TNC table
# kept 295143 rows in weekend TNC table
# Read 925000 rows and kept 621732 rows in weekday TNC table
# kept 303268 rows in weekend TNC table
# Read 950000 rows and kept 638483 rows in weekday TNC table
# kept 311517 rows in weekend TNC table
# Read 975000 rows and kept 655263 rows in weekday TNC table
# kept 319737 rows in weekend TNC table
# Read 1000000 rows and kept 671869 rows in weekday TNC table
# kept 328131 rows in weekend TNC table
# Read 1025000 rows and kept 688542 rows in weekday TNC table
# kept 336458 rows in weekend TNC table
# Read 1050000 rows and kept 705520 rows in weekday TNC table
# kept 344480 rows in weekend TNC table
# Read 1075000 rows and kept 722285 rows in weekday TNC table
# kept 352715 rows in weekend TNC table
# Read 1100000 rows and kept 739064 rows in weekday TNC table
# kept 360936 rows in weekend TNC table
# Read 1125000 rows and kept 755800 rows in weekday TNC table
# kept 369200 rows in weekend TNC table
# Read 1150000 rows and kept 772603 rows in weekday TNC table
# kept 377397 rows in weekend TNC table
# Read 1175000 rows and kept 789561 rows in weekday TNC table
# kept 385439 rows in weekend TNC table
# Read 1200000 rows and kept 806433 rows in weekday TNC table
# kept 393567 rows in weekend TNC table
# Read 1225000 rows and kept 823268 rows in weekday TNC table
# kept 401732 rows in weekend TNC table
# Read 1250000 rows and kept 840046 rows in weekday TNC table
# kept 409954 rows in weekend TNC table
# Read 1275000 rows and kept 856830 rows in weekday TNC table
# kept 418170 rows in weekend TNC table
# Read 1300000 rows and kept 873647 rows in weekday TNC table
# kept 426353 rows in weekend TNC table
# Read 1325000 rows and kept 890597 rows in weekday TNC table
# kept 434403 rows in weekend TNC table
# Read 1350000 rows and kept 907438 rows in weekday TNC table
# kept 442562 rows in weekend TNC table
# Read 1375000 rows and kept 924239 rows in weekday TNC table
# kept 450761 rows in weekend TNC table
# Read 1400000 rows and kept 940911 rows in weekday TNC table
# kept 459089 rows in weekend TNC table
# Read 1425000 rows and kept 957828 rows in weekday TNC table
# kept 467172 rows in weekend TNC table
# Read 1450000 rows and kept 974596 rows in weekday TNC table
# kept 475404 rows in weekend TNC table
# Read 1475000 rows and kept 991388 rows in weekday TNC table
# kept 483612 rows in weekend TNC table
# Read 1500000 rows and kept 1008172 rows in weekday TNC table
# kept 491828 rows in weekend TNC table
# Read 1525000 rows and kept 1024972 rows in weekday TNC table
# kept 500028 rows in weekend TNC table
# Read 1550000 rows and kept 1041798 rows in weekday TNC table
# kept 508202 rows in weekend TNC table
# Read 1575000 rows and kept 1058502 rows in weekday TNC table
# kept 516498 rows in weekend TNC table
# Read 1600000 rows and kept 1075369 rows in weekday TNC table
# kept 524631 rows in weekend TNC table
# Read 1625000 rows and kept 1092135 rows in weekday TNC table
# kept 532865 rows in weekend TNC table
# Read 1650000 rows and kept 1108957 rows in weekday TNC table
# kept 541043 rows in weekend TNC table
# Read 1675000 rows and kept 1125845 rows in weekday TNC table
# kept 549155 rows in weekend TNC table
# Read 1700000 rows and kept 1142793 rows in weekday TNC table
# kept 557207 rows in weekend TNC table
# Read 1725000 rows and kept 1159700 rows in weekday TNC table
# kept 565300 rows in weekend TNC table
# Read 1750000 rows and kept 1176387 rows in weekday TNC table
# kept 573613 rows in weekend TNC table
# Read 1775000 rows and kept 1193255 rows in weekday TNC table
# kept 581745 rows in weekend TNC table
# Read 1800000 rows and kept 1210046 rows in weekday TNC table
# kept 589954 rows in weekend TNC table
# Read 1825000 rows and kept 1226864 rows in weekday TNC table
# kept 598136 rows in weekend TNC table
# Read 1850000 rows and kept 1243733 rows in weekday TNC table
# kept 606267 rows in weekend TNC table
# Read 1875000 rows and kept 1260544 rows in weekday TNC table
# kept 614456 rows in weekend TNC table
# Read 1900000 rows and kept 1277330 rows in weekday TNC table
# kept 622670 rows in weekend TNC table
# Read 1925000 rows and kept 1294237 rows in weekday TNC table
# kept 630763 rows in weekend TNC table
# Read 1950000 rows and kept 1311103 rows in weekday TNC table
# kept 638897 rows in weekend TNC table
# Read 1975000 rows and kept 1327756 rows in weekday TNC table
# kept 647244 rows in weekend TNC table
# Read 2000000 rows and kept 1344548 rows in weekday TNC table
# kept 655452 rows in weekend TNC table
# Read 2025000 rows and kept 1361289 rows in weekday TNC table
# kept 663711 rows in weekend TNC table
# Read 2050000 rows and kept 1378127 rows in weekday TNC table
# kept 671873 rows in weekend TNC table
# Read 2075000 rows and kept 1394941 rows in weekday TNC table
# kept 680059 rows in weekend TNC table
# Read 2100000 rows and kept 1411791 rows in weekday TNC table
# kept 688209 rows in weekend TNC table
# Read 2125000 rows and kept 1428618 rows in weekday TNC table
# kept 696382 rows in weekend TNC table
# Read 2150000 rows and kept 1445488 rows in weekday TNC table
# kept 704512 rows in weekend TNC table
# Read 2175000 rows and kept 1462290 rows in weekday TNC table
# kept 712710 rows in weekend TNC table
# Read 2200000 rows and kept 1479172 rows in weekday TNC table
# kept 720828 rows in weekend TNC table
# Read 2225000 rows and kept 1495794 rows in weekday TNC table
# kept 729206 rows in weekend TNC table
# Read 2250000 rows and kept 1512524 rows in weekday TNC table
# kept 737476 rows in weekend TNC table
# Read 2275000 rows and kept 1529356 rows in weekday TNC table
# kept 745644 rows in weekend TNC table
# Read 2300000 rows and kept 1546230 rows in weekday TNC table
# kept 753770 rows in weekend TNC table
# Read 2325000 rows and kept 1562905 rows in weekday TNC table
# kept 762095 rows in weekend TNC table
# Read 2350000 rows and kept 1579800 rows in weekday TNC table
# kept 770200 rows in weekend TNC table
# Read 2375000 rows and kept 1596650 rows in weekday TNC table
# kept 778350 rows in weekend TNC table
# Read 2400000 rows and kept 1613437 rows in weekday TNC table
# kept 786563 rows in weekend TNC table
# Read 2425000 rows and kept 1630201 rows in weekday TNC table
# kept 794799 rows in weekend TNC table
# Read 2450000 rows and kept 1647001 rows in weekday TNC table
# kept 802999 rows in weekend TNC table
# Read 2475000 rows and kept 1663809 rows in weekday TNC table
# kept 811191 rows in weekend TNC table
# Read 2500000 rows and kept 1680560 rows in weekday TNC table
# kept 819440 rows in weekend TNC table
# Read 2525000 rows and kept 1697362 rows in weekday TNC table
# kept 827638 rows in weekend TNC table
# Read 2550000 rows and kept 1714166 rows in weekday TNC table
# kept 835834 rows in weekend TNC table
# Read 2575000 rows and kept 1731028 rows in weekday TNC table
# kept 843972 rows in weekend TNC table
# Read 2600000 rows and kept 1747772 rows in weekday TNC table
# kept 852228 rows in weekend TNC table
# Read 2625000 rows and kept 1764527 rows in weekday TNC table
# kept 860473 rows in weekend TNC table
# Read 2650000 rows and kept 1781424 rows in weekday TNC table
# kept 868576 rows in weekend TNC table
# Read 2675000 rows and kept 1798273 rows in weekday TNC table
# kept 876727 rows in weekend TNC table
# Read 2700000 rows and kept 1815024 rows in weekday TNC table
# kept 884976 rows in weekend TNC table
# Read 2725000 rows and kept 1831739 rows in weekday TNC table
# kept 893261 rows in weekend TNC table
# Read 2750000 rows and kept 1848655 rows in weekday TNC table
# kept 901345 rows in weekend TNC table
# Read 2775000 rows and kept 1865563 rows in weekday TNC table
# kept 909437 rows in weekend TNC table
# Read 2800000 rows and kept 1882324 rows in weekday TNC table
# kept 917676 rows in weekend TNC table
# Read 2825000 rows and kept 1899111 rows in weekday TNC table
# kept 925889 rows in weekend TNC table
# Read 2850000 rows and kept 1915990 rows in weekday TNC table
# kept 934010 rows in weekend TNC table
# Read 2875000 rows and kept 1932935 rows in weekday TNC table
# kept 942065 rows in weekend TNC table
# Read 2900000 rows and kept 1949822 rows in weekday TNC table
# kept 950178 rows in weekend TNC table
# Read 2925000 rows and kept 1966731 rows in weekday TNC table
# kept 958269 rows in weekend TNC table
# Read 2950000 rows and kept 1983520 rows in weekday TNC table
# kept 966480 rows in weekend TNC table
# Read 2975000 rows and kept 2000451 rows in weekday TNC table
# kept 974549 rows in weekend TNC table
# Read 3000000 rows and kept 2017280 rows in weekday TNC table
# kept 982720 rows in weekend TNC table
# Read 3025000 rows and kept 2034075 rows in weekday TNC table
# kept 990925 rows in weekend TNC table
# Read 3050000 rows and kept 2050900 rows in weekday TNC table
# kept 999100 rows in weekend TNC table
# Read 3075000 rows and kept 2067775 rows in weekday TNC table
# kept 1007225 rows in weekend TNC table
# Read 3100000 rows and kept 2084709 rows in weekday TNC table
# kept 1015291 rows in weekend TNC table
# Read 3125000 rows and kept 2101470 rows in weekday TNC table
# kept 1023530 rows in weekend TNC table
# Read 3150000 rows and kept 2118300 rows in weekday TNC table
# kept 1031700 rows in weekend TNC table
# Read 3175000 rows and kept 2135146 rows in weekday TNC table
# kept 1039854 rows in weekend TNC table
# Read 3200000 rows and kept 2151972 rows in weekday TNC table
# kept 1048028 rows in weekend TNC table
# Read 3225000 rows and kept 2168764 rows in weekday TNC table
# kept 1056236 rows in weekend TNC table
# Read 3250000 rows and kept 2185490 rows in weekday TNC table
# kept 1064510 rows in weekend TNC table
# Read 3275000 rows and kept 2202204 rows in weekday TNC table
# kept 1072796 rows in weekend TNC table
# Read 3300000 rows and kept 2219076 rows in weekday TNC table
# kept 1080924 rows in weekend TNC table
# Read 3325000 rows and kept 2235870 rows in weekday TNC table
# kept 1089130 rows in weekend TNC table
# Read 3350000 rows and kept 2252669 rows in weekday TNC table
# kept 1097331 rows in weekend TNC table
# Read 3375000 rows and kept 2269412 rows in weekday TNC table
# kept 1105588 rows in weekend TNC table
# Read 3400000 rows and kept 2286255 rows in weekday TNC table
# kept 1113745 rows in weekend TNC table
# Read 3425000 rows and kept 2303066 rows in weekday TNC table
# kept 1121934 rows in weekend TNC table
# Read 3450000 rows and kept 2319833 rows in weekday TNC table
# kept 1130167 rows in weekend TNC table
# Read 3475000 rows and kept 2336600 rows in weekday TNC table
# kept 1138400 rows in weekend TNC table
# Read 3500000 rows and kept 2353272 rows in weekday TNC table
# kept 1146728 rows in weekend TNC table
# Read 3525000 rows and kept 2370051 rows in weekday TNC table
# kept 1154949 rows in weekend TNC table
# Read 3550000 rows and kept 2386776 rows in weekday TNC table
# kept 1163224 rows in weekend TNC table
# Read 3575000 rows and kept 2403585 rows in weekday TNC table
# kept 1171415 rows in weekend TNC table
# Read 3600000 rows and kept 2420384 rows in weekday TNC table
# kept 1179616 rows in weekend TNC table
# Read 3625000 rows and kept 2437160 rows in weekday TNC table
# kept 1187840 rows in weekend TNC table
# Read 3650000 rows and kept 2453963 rows in weekday TNC table
# kept 1196037 rows in weekend TNC table
# Read 3675000 rows and kept 2470696 rows in weekday TNC table
# kept 1204304 rows in weekend TNC table
# Read 3700000 rows and kept 2487477 rows in weekday TNC table
# kept 1212523 rows in weekend TNC table
# Read 3725000 rows and kept 2504284 rows in weekday TNC table
# kept 1220716 rows in weekend TNC table
# Read 3750000 rows and kept 2520995 rows in weekday TNC table
# kept 1229005 rows in weekend TNC table
# Read 3775000 rows and kept 2537780 rows in weekday TNC table
# kept 1237220 rows in weekend TNC table
# Read 3800000 rows and kept 2554493 rows in weekday TNC table
# kept 1245507 rows in weekend TNC table
# Read 3825000 rows and kept 2571415 rows in weekday TNC table
# kept 1253585 rows in weekend TNC table
# Read 3850000 rows and kept 2588203 rows in weekday TNC table
# kept 1261797 rows in weekend TNC table
# Read 3875000 rows and kept 2604982 rows in weekday TNC table
# kept 1270018 rows in weekend TNC table
# Read 3900000 rows and kept 2621833 rows in weekday TNC table
# kept 1278167 rows in weekend TNC table
# Read 3925000 rows and kept 2638573 rows in weekday TNC table
# kept 1286427 rows in weekend TNC table
# Read 3950000 rows and kept 2655440 rows in weekday TNC table
# kept 1294560 rows in weekend TNC table
# Read 3975000 rows and kept 2672287 rows in weekday TNC table
# kept 1302713 rows in weekend TNC table
# Read 4000000 rows and kept 2689123 rows in weekday TNC table
# kept 1310877 rows in weekend TNC table
# Read 4025000 rows and kept 2705928 rows in weekday TNC table
# kept 1319072 rows in weekend TNC table
# Read 4050000 rows and kept 2722830 rows in weekday TNC table
# kept 1327170 rows in weekend TNC table
# Read 4075000 rows and kept 2739675 rows in weekday TNC table
# kept 1335325 rows in weekend TNC table
# Read 4100000 rows and kept 2756533 rows in weekday TNC table
# kept 1343467 rows in weekend TNC table
# Read 4125000 rows and kept 2773415 rows in weekday TNC table
# kept 1351585 rows in weekend TNC table
# Read 4150000 rows and kept 2790322 rows in weekday TNC table
# kept 1359678 rows in weekend TNC table
# Read 4175000 rows and kept 2807107 rows in weekday TNC table
# kept 1367893 rows in weekend TNC table
# Read 4200000 rows and kept 2823754 rows in weekday TNC table
# kept 1376246 rows in weekend TNC table
# Read 4225000 rows and kept 2840487 rows in weekday TNC table
# kept 1384513 rows in weekend TNC table
# Read 4250000 rows and kept 2857319 rows in weekday TNC table
# kept 1392681 rows in weekend TNC table
# Read 4275000 rows and kept 2874228 rows in weekday TNC table
# kept 1400772 rows in weekend TNC table
# Read 4300000 rows and kept 2890913 rows in weekday TNC table
# kept 1409087 rows in weekend TNC table
# Read 4325000 rows and kept 2907671 rows in weekday TNC table
# kept 1417329 rows in weekend TNC table
# Read 4350000 rows and kept 2924417 rows in weekday TNC table
# kept 1425583 rows in weekend TNC table
# Read 4375000 rows and kept 2941286 rows in weekday TNC table
# kept 1433714 rows in weekend TNC table
# Read 4400000 rows and kept 2958236 rows in weekday TNC table
# kept 1441764 rows in weekend TNC table
# Read 4425000 rows and kept 2974949 rows in weekday TNC table
# kept 1450051 rows in weekend TNC table
# Read 4450000 rows and kept 2991673 rows in weekday TNC table
# kept 1458327 rows in weekend TNC table
# Read 4475000 rows and kept 3008498 rows in weekday TNC table
# kept 1466502 rows in weekend TNC table
# Read 4500000 rows and kept 3025234 rows in weekday TNC table
# kept 1474766 rows in weekend TNC table
# Read 4525000 rows and kept 3042032 rows in weekday TNC table
# kept 1482968 rows in weekend TNC table
# Read 4550000 rows and kept 3058809 rows in weekday TNC table
# kept 1491191 rows in weekend TNC table
# Read 4575000 rows and kept 3075617 rows in weekday TNC table
# kept 1499383 rows in weekend TNC table
# Read 4600000 rows and kept 3092392 rows in weekday TNC table
# kept 1507608 rows in weekend TNC table
# Read 4625000 rows and kept 3109284 rows in weekday TNC table
# kept 1515716 rows in weekend TNC table
# Read 4650000 rows and kept 3126161 rows in weekday TNC table
# kept 1523839 rows in weekend TNC table
# Read 4675000 rows and kept 3142913 rows in weekday TNC table
# kept 1532087 rows in weekend TNC table
# Read 4700000 rows and kept 3159676 rows in weekday TNC table
# kept 1540324 rows in weekend TNC table
# Read 4725000 rows and kept 3176540 rows in weekday TNC table
# kept 1548460 rows in weekend TNC table
# Read 4750000 rows and kept 3193269 rows in weekday TNC table
# kept 1556731 rows in weekend TNC table
# Read 4775000 rows and kept 3210010 rows in weekday TNC table
# kept 1564990 rows in weekend TNC table
# Read 4800000 rows and kept 3226848 rows in weekday TNC table
# kept 1573152 rows in weekend TNC table
# Read 4825000 rows and kept 3243688 rows in weekday TNC table
# kept 1581312 rows in weekend TNC table
# Read 4850000 rows and kept 3260517 rows in weekday TNC table
# kept 1589483 rows in weekend TNC table
# Read 4875000 rows and kept 3277293 rows in weekday TNC table
# kept 1597707 rows in weekend TNC table
# Read 4900000 rows and kept 3294117 rows in weekday TNC table
# kept 1605883 rows in weekend TNC table
# Read 4925000 rows and kept 3310919 rows in weekday TNC table
# kept 1614081 rows in weekend TNC table
# Read 4950000 rows and kept 3327806 rows in weekday TNC table
# kept 1622194 rows in weekend TNC table
# Read 4975000 rows and kept 3344766 rows in weekday TNC table
# kept 1630234 rows in weekend TNC table
# Read 5000000 rows and kept 3361484 rows in weekday TNC table
# kept 1638516 rows in weekend TNC table
# Read 5025000 rows and kept 3378277 rows in weekday TNC table
# kept 1646723 rows in weekend TNC table
# ...
# kept 5386423 rows in weekend TNC table
# Read 16350000 rows and kept 10955185 rows in weekday TNC table
# kept 5394815 rows in weekend TNC table
# Read 16375000 rows and kept 10971922 rows in weekday TNC table
# kept 5403078 rows in weekend TNC table
# Read 16400000 rows and kept 10988629 rows in weekday TNC table
# kept 5411371 rows in weekend TNC table
# Read 16425000 rows and kept 11005377 rows in weekday TNC table
# kept 5419623 rows in weekend TNC table
# Read 16450000 rows and kept 11022110 rows in weekday TNC table
# kept 5427890 rows in weekend TNC table
# Read 16475000 rows and kept 11038819 rows in weekday TNC table
# kept 5436181 rows in weekend TNC table
# Read 16500000 rows and kept 11055452 rows in weekday TNC table
# kept 5444548 rows in weekend TNC table
# Read 16525000 rows and kept 11072279 rows in weekday TNC table
# kept 5452721 rows in weekend TNC table
# Read 16550000 rows and kept 11089010 rows in weekday TNC table
# kept 5460990 rows in weekend TNC table
# Read 16575000 rows and kept 11105628 rows in weekday TNC table
# kept 5469372 rows in weekend TNC table
# Read 16600000 rows and kept 11122210 rows in weekday TNC table
# kept 5477790 rows in weekend TNC table
# Read 16625000 rows and kept 11138745 rows in weekday TNC table
# kept 5486255 rows in weekend TNC table
# Read 16650000 rows and kept 11155412 rows in weekday TNC table
# kept 5494588 rows in weekend TNC table
# Read 16675000 rows and kept 11172071 rows in weekday TNC table
# kept 5502929 rows in weekend TNC table
# Read 16700000 rows and kept 11188813 rows in weekday TNC table
# kept 5511187 rows in weekend TNC table
# Read 16725000 rows and kept 11205577 rows in weekday TNC table
# kept 5519423 rows in weekend TNC table
# Read 16750000 rows and kept 11222215 rows in weekday TNC table
# kept 5527785 rows in weekend TNC table
# Read 16775000 rows and kept 11238875 rows in weekday TNC table
# kept 5536125 rows in weekend TNC table
# Read 16800000 rows and kept 11255564 rows in weekday TNC table
# kept 5544436 rows in weekend TNC table
# Read 16825000 rows and kept 11272206 rows in weekday TNC table
# kept 5552794 rows in weekend TNC table
# Read 16850000 rows and kept 11288824 rows in weekday TNC table
# kept 5561176 rows in weekend TNC table
# Read 16875000 rows and kept 11305606 rows in weekday TNC table
# kept 5569394 rows in weekend TNC table
# Read 16900000 rows and kept 11322310 rows in weekday TNC table
# kept 5577690 rows in weekend TNC table
# Read 16925000 rows and kept 11339121 rows in weekday TNC table
# kept 5585879 rows in weekend TNC table
# Read 16950000 rows and kept 11355750 rows in weekday TNC table
# kept 5594250 rows in weekend TNC table
# Read 16975000 rows and kept 11372279 rows in weekday TNC table
# kept 5602721 rows in weekend TNC table
# Read 17000000 rows and kept 11388992 rows in weekday TNC table
# kept 5611008 rows in weekend TNC table
# Read 17025000 rows and kept 11405739 rows in weekday TNC table
# kept 5619261 rows in weekend TNC table
# Read 17050000 rows and kept 11422453 rows in weekday TNC table
# kept 5627547 rows in weekend TNC table
# Read 17075000 rows and kept 11439184 rows in weekday TNC table
# kept 5635816 rows in weekend TNC table
# Read 17100000 rows and kept 11455842 rows in weekday TNC table
# kept 5644158 rows in weekend TNC table
# Read 17125000 rows and kept 11472805 rows in weekday TNC table
# kept 5652195 rows in weekend TNC table
# Read 17150000 rows and kept 11489527 rows in weekday TNC table
# kept 5660473 rows in weekend TNC table
# Read 17175000 rows and kept 11506188 rows in weekday TNC table
# kept 5668812 rows in weekend TNC table
# Read 17200000 rows and kept 11522977 rows in weekday TNC table
# kept 5677023 rows in weekend TNC table
# Read 17225000 rows and kept 11539606 rows in weekday TNC table
# kept 5685394 rows in weekend TNC table
# Read 17250000 rows and kept 11556397 rows in weekday TNC table
# kept 5693603 rows in weekend TNC table
# Read 17275000 rows and kept 11573199 rows in weekday TNC table
# kept 5701801 rows in weekend TNC table
# Read 17300000 rows and kept 11589776 rows in weekday TNC table
# kept 5710224 rows in weekend TNC table
# Read 17325000 rows and kept 11606601 rows in weekday TNC table
# kept 5718399 rows in weekend TNC table
# Read 17350000 rows and kept 11623253 rows in weekday TNC table
# kept 5726747 rows in weekend TNC table
# Read 17375000 rows and kept 11640061 rows in weekday TNC table
# kept 5734939 rows in weekend TNC table
# Read 17400000 rows and kept 11656729 rows in weekday TNC table
# kept 5743271 rows in weekend TNC table
# Read 17425000 rows and kept 11673552 rows in weekday TNC table
# kept 5751448 rows in weekend TNC table
# Read 17450000 rows and kept 11690212 rows in weekday TNC table
# kept 5759788 rows in weekend TNC table
# Read 17475000 rows and kept 11706722 rows in weekday TNC table
# kept 5768278 rows in weekend TNC table
# Read 17500000 rows and kept 11723477 rows in weekday TNC table
# kept 5776523 rows in weekend TNC table
# Read 17525000 rows and kept 11740158 rows in weekday TNC table
# kept 5784842 rows in weekend TNC table
# Read 17550000 rows and kept 11756872 rows in weekday TNC table
# kept 5793128 rows in weekend TNC table
# Read 17575000 rows and kept 11773548 rows in weekday TNC table
# kept 5801452 rows in weekend TNC table
# Read 17600000 rows and kept 11790238 rows in weekday TNC table
# kept 5809762 rows in weekend TNC table
# Read 17625000 rows and kept 11806957 rows in weekday TNC table
# kept 5818043 rows in weekend TNC table
# Read 17650000 rows and kept 11824428 rows in weekday TNC table
# kept 5825572 rows in weekend TNC table
# Read 17675000 rows and kept 11841816 rows in weekday TNC table
# kept 5833184 rows in weekend TNC table
# Read 17700000 rows and kept 11859204 rows in weekday TNC table
# kept 5840796 rows in weekend TNC table
# Read 17725000 rows and kept 11876630 rows in weekday TNC table
# kept 5848370 rows in weekend TNC table
# Read 17750000 rows and kept 11893955 rows in weekday TNC table
# kept 5856045 rows in weekend TNC table
# Read 17775000 rows and kept 11911290 rows in weekday TNC table
# kept 5863710 rows in weekend TNC table
# Read 17800000 rows and kept 11928832 rows in weekday TNC table
# kept 5871168 rows in weekend TNC table
# Read 17825000 rows and kept 11946083 rows in weekday TNC table
# kept 5878917 rows in weekend TNC table
# Read 17850000 rows and kept 11969915 rows in weekday TNC table
# kept 5880085 rows in weekend TNC table
# Read 17875000 rows and kept 11994915 rows in weekday TNC table
# kept 5880085 rows in weekend TNC table
# Read 17900000 rows and kept 12019915 rows in weekday TNC table
# kept 5880085 rows in weekend TNC table
# Read 17925000 rows and kept 12044915 rows in weekday TNC table
# kept 5880085 rows in weekend TNC table
# Read 17950000 rows and kept 12069915 rows in weekday TNC table
# kept 5880085 rows in weekend TNC table
# Read 17975000 rows and kept 12094915 rows in weekday TNC table
# kept 5880085 rows in weekend TNC table
# Read 18000000 rows and kept 12119915 rows in weekday TNC table
# kept 5880085 rows in weekend TNC table
# Read 18025000 rows and kept 12144915 rows in weekday TNC table
# kept 5880085 rows in weekend TNC table
# Read 18050000 rows and kept 12169915 rows in weekday TNC table
# kept 5880085 rows in weekend TNC table
# Read 18075000 rows and kept 12194915 rows in weekday TNC table
# kept 5880085 rows in weekend TNC table
# Read 18100000 rows and kept 12219915 rows in weekday TNC table
# kept 5880085 rows in weekend TNC table
# Read 18125000 rows and kept 12244915 rows in weekday TNC table
# kept 5880085 rows in weekend TNC table
# Read 18150000 rows and kept 12269915 rows in weekday TNC table
# kept 5880085 rows in weekend TNC table
# Read 18175000 rows and kept 12294915 rows in weekday TNC table
# kept 5880085 rows in weekend TNC table
# Read 18200000 rows and kept 12319915 rows in weekday TNC table
# kept 5880085 rows in weekend TNC table
# Read 18225000 rows and kept 12344915 rows in weekday TNC table
# kept 5880085 rows in weekend TNC table
# Read 18250000 rows and kept 12369914 rows in weekday TNC table
# kept 5880086 rows in weekend TNC table
# Read 18275000 rows and kept 12394914 rows in weekday TNC table
# kept 5880086 rows in weekend TNC table
# Read 18300000 rows and kept 12419914 rows in weekday TNC table
# kept 5880086 rows in weekend TNC table
# Read 18325000 rows and kept 12444914 rows in weekday TNC table
# kept 5880086 rows in weekend TNC table
# Read 18350000 rows and kept 12469913 rows in weekday TNC table
# kept 5880087 rows in weekend TNC table
# Read 18375000 rows and kept 12494913 rows in weekday TNC table
# kept 5880087 rows in weekend TNC table
# Read 18400000 rows and kept 12519913 rows in weekday TNC table
# kept 5880087 rows in weekend TNC table
# Read 18425000 rows and kept 12544913 rows in weekday TNC table
# kept 5880087 rows in weekend TNC table
# Read 18450000 rows and kept 12569913 rows in weekday TNC table
# kept 5880087 rows in weekend TNC table
# Read 18475000 rows and kept 12594913 rows in weekday TNC table
# kept 5880087 rows in weekend TNC table
# Read 18500000 rows and kept 12619913 rows in weekday TNC table
# kept 5880087 rows in weekend TNC table
# Read 18525000 rows and kept 12644913 rows in weekday TNC table
# kept 5880087 rows in weekend TNC table
# Read 18550000 rows and kept 12669913 rows in weekday TNC table
# kept 5880087 rows in weekend TNC table
# Read 18575000 rows and kept 12694909 rows in weekday TNC table
# kept 5880091 rows in weekend TNC table
# Read 18600000 rows and kept 12719909 rows in weekday TNC table
# kept 5880091 rows in weekend TNC table
# Read 18625000 rows and kept 12744909 rows in weekday TNC table
# kept 5880091 rows in weekend TNC table
# Read 18650000 rows and kept 12769909 rows in weekday TNC table
# kept 5880091 rows in weekend TNC table
# Read 18675000 rows and kept 12794909 rows in weekday TNC table
# kept 5880091 rows in weekend TNC table
# Read 18700000 rows and kept 12819909 rows in weekday TNC table
# kept 5880091 rows in weekend TNC table
# Read 18725000 rows and kept 12844909 rows in weekday TNC table
# kept 5880091 rows in weekend TNC table
# Read 18750000 rows and kept 12869909 rows in weekday TNC table
# kept 5880091 rows in weekend TNC table
# Read 18775000 rows and kept 12894909 rows in weekday TNC table
# kept 5880091 rows in weekend TNC table
# Read 18800000 rows and kept 12919908 rows in weekday TNC table
# kept 5880092 rows in weekend TNC table
# Read 18825000 rows and kept 12944908 rows in weekday TNC table
# kept 5880092 rows in weekend TNC table
# Read 18850000 rows and kept 12969908 rows in weekday TNC table
# kept 5880092 rows in weekend TNC table
# Read 18875000 rows and kept 12994908 rows in weekday TNC table
# kept 5880092 rows in weekend TNC table
# Read 18900000 rows and kept 13019908 rows in weekday TNC table
# kept 5880092 rows in weekend TNC table
# Read 18925000 rows and kept 13044887 rows in weekday TNC table
# kept 5880113 rows in weekend TNC table
# Read 18950000 rows and kept 13066127 rows in weekday TNC table
# kept 5883873 rows in weekend TNC table
# Read 18975000 rows and kept 13066127 rows in weekday TNC table
# kept 5908873 rows in weekend TNC table
# Read 19000000 rows and kept 13069996 rows in weekday TNC table
# kept 5930004 rows in weekend TNC table
# Read 19025000 rows and kept 13081508 rows in weekday TNC table
# kept 5943492 rows in weekend TNC table
# Read 19050000 rows and kept 13092974 rows in weekday TNC table
# kept 5957026 rows in weekend TNC table
# Read 19075000 rows and kept 13104695 rows in weekday TNC table
# kept 5970305 rows in weekend TNC table
# Read 19100000 rows and kept 13116188 rows in weekday TNC table
# kept 5983812 rows in weekend TNC table
# Read 19125000 rows and kept 13127535 rows in weekday TNC table
# kept 5997465 rows in weekend TNC table
# Read 19150000 rows and kept 13139025 rows in weekday TNC table
# kept 6010975 rows in weekend TNC table
# Read 19175000 rows and kept 13150545 rows in weekday TNC table
# kept 6024455 rows in weekend TNC table
# Read 19200000 rows and kept 13161922 rows in weekday TNC table
# kept 6038078 rows in weekend TNC table
# Read 19225000 rows and kept 13173508 rows in weekday TNC table
# kept 6051492 rows in weekend TNC table
# Read 19250000 rows and kept 13185038 rows in weekday TNC table
# kept 6064962 rows in weekend TNC table
# Read 19275000 rows and kept 13196536 rows in weekday TNC table
# kept 6078464 rows in weekend TNC table
# Read 19300000 rows and kept 13207981 rows in weekday TNC table
# kept 6092019 rows in weekend TNC table
# Read 19325000 rows and kept 13219670 rows in weekday TNC table
# kept 6105330 rows in weekend TNC table
# Read 19350000 rows and kept 13231196 rows in weekday TNC table
# kept 6118804 rows in weekend TNC table
# Read 19375000 rows and kept 13242724 rows in weekday TNC table
# kept 6132276 rows in weekend TNC table
# Read 19400000 rows and kept 13254248 rows in weekday TNC table
# kept 6145752 rows in weekend TNC table
# Read 19425000 rows and kept 13265606 rows in weekday TNC table
# kept 6159394 rows in weekend TNC table
# Read 19450000 rows and kept 13277003 rows in weekday TNC table
# kept 6172997 rows in weekend TNC table
# Read 19475000 rows and kept 13288564 rows in weekday TNC table
# kept 6186436 rows in weekend TNC table
# Read 19500000 rows and kept 13300012 rows in weekday TNC table
# kept 6199988 rows in weekend TNC table
# Read 19525000 rows and kept 13313136 rows in weekday TNC table
# kept 6211864 rows in weekend TNC table
# Read 19550000 rows and kept 13330396 rows in weekday TNC table
# kept 6219604 rows in weekend TNC table
# Read 19575000 rows and kept 13347733 rows in weekday TNC table
# kept 6227267 rows in weekend TNC table
# Read 19600000 rows and kept 13365174 rows in weekday TNC table
# kept 6234826 rows in weekend TNC table
# Read 19625000 rows and kept 13382513 rows in weekday TNC table
# kept 6242487 rows in weekend TNC table
# Read 19650000 rows and kept 13399918 rows in weekday TNC table
# kept 6250082 rows in weekend TNC table
# Read 19675000 rows and kept 13417389 rows in weekday TNC table
# kept 6257611 rows in weekend TNC table
# Read 19700000 rows and kept 13434713 rows in weekday TNC table
# kept 6265287 rows in weekend TNC table
# Read 19725000 rows and kept 13452068 rows in weekday TNC table
# kept 6272932 rows in weekend TNC table
# Read 19750000 rows and kept 13469432 rows in weekday TNC table
# kept 6280568 rows in weekend TNC table
# Read 19775000 rows and kept 13486682 rows in weekday TNC table
# kept 6288318 rows in weekend TNC table
# Read 19800000 rows and kept 13503993 rows in weekday TNC table
# kept 6296007 rows in weekend TNC table
# Read 19825000 rows and kept 13521430 rows in weekday TNC table
# kept 6303570 rows in weekend TNC table
# Read 19850000 rows and kept 13538838 rows in weekday TNC table
# kept 6311162 rows in weekend TNC table
# Read 19875000 rows and kept 13556355 rows in weekday TNC table
# kept 6318645 rows in weekend TNC table
# Read 19900000 rows and kept 13573844 rows in weekday TNC table
# kept 6326156 rows in weekend TNC table
# Read 19925000 rows and kept 13591170 rows in weekday TNC table
# kept 6333830 rows in weekend TNC table
# Read 19950000 rows and kept 13608586 rows in weekday TNC table
# kept 6341414 rows in weekend TNC table
# Read 19975000 rows and kept 13625929 rows in weekday TNC table
# kept 6349071 rows in weekend TNC table
# Read 20000000 rows and kept 13643248 rows in weekday TNC table
# kept 6356752 rows in weekend TNC table
# Read 20025000 rows and kept 13660637 rows in weekday TNC table
# kept 6364363 rows in weekend TNC table
# Read 20050000 rows and kept 13678096 rows in weekday TNC table
# kept 6371904 rows in weekend TNC table
# Read 20075000 rows and kept 13695449 rows in weekday TNC table
# kept 6379551 rows in weekend TNC table
# Read 20100000 rows and kept 13712770 rows in weekday TNC table
# kept 6387230 rows in weekend TNC table
# Read 20125000 rows and kept 13730145 rows in weekday TNC table
# kept 6394855 rows in weekend TNC table
# Read 20150000 rows and kept 13747443 rows in weekday TNC table
# kept 6402557 rows in weekend TNC table
# Read 20175000 rows and kept 13764840 rows in weekday TNC table
# kept 6410160 rows in weekend TNC table
# Read 20200000 rows and kept 13782198 rows in weekday TNC table
# kept 6417802 rows in weekend TNC table
# Read 20225000 rows and kept 13799603 rows in weekday TNC table
# kept 6425397 rows in weekend TNC table
