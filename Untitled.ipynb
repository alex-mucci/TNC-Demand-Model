# %%
import pandas as pd

# %%
acs_dp04 = pd.read_csv('C:/Workspace/TNC-Demand-Model/Inputs/ACS/2018/ACSDP1Y2018.DP04_data_with_overlays_2020-09-07T121132.csv')

# %%
acs_dp04
# Out:
#       GEO_ID                  NAME  \
# 0         id  Geographic Area Name
# 1  0100000US         United States
#
#                                           DP04_0039M  \
# 0  Margin of Error!!BEDROOMS!!Total housing units...
# 1                                              33006
#
#                                          DP04_0039PE  \
# 0  Percent Estimate!!BEDROOMS!!Total housing unit...
# 1                                                2.6
#
#                                          DP04_0039PM  \
# 0  Percent Margin of Error!!BEDROOMS!!Total housi...
# 1                                                0.1
#
#                                           DP04_0040E  \
# 0  Estimate!!BEDROOMS!!Total housing units!!1 bed...
# 1                                           15118145
#
#                                           DP04_0040M  \
# 0  Margin of Error!!BEDROOMS!!Total housing units...
# 1                                              64983
#
# ...
